# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}appid={weather_api_key}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | torre de moncorvo
# Processing Record 3 of Set 1 | codrington
# Processing Record 4 of Set 1 | kajiado
# Processing Record 5 of Set 1 | waitangi
# Processing Record 6 of Set 1 | qaqortoq
# Processing Record 7 of Set 1 | invercargill
# Processing Record 8 of Set 1 | razole
# Processing Record 9 of Set 1 | vilyuchinsk
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | yaren
# Processing Record 14 of Set 1 | slave lake
# Processing Record 15 of Set 1 | urangan
# Processing Record 16 of Set 1 | itoman
# Processing Record 17 of Set 1 | uzgen
# Processing Record 18 of Set 1 | isafjordur
# Processing Record 19 of Set 1 | buka
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | grand falls-windsor
# Processing Record 23 of Set 1 | pitimbu
# Processing Record 24 of Set 1 | mili
# Processing Record 25 of Set 1 | ust-nera
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | isabela
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | hawaiian paradise park
# Processing Record 31 of Set 1 | huadian
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | conil de la frontera
# Processing Record 34 of Set 1 | suva
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | jagraon
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | bayanhongor
# Processing Record 39 of Set 1 | minas de marcona
# Processing Record 40 of Set 1 | moissala
# Processing Record 41 of Set 1 | zhangye
# Processing Record 42 of Set 1 | aleg
# Processing Record 43 of Set 1 | yeppoon
# Processing Record 44 of Set 1 | bikapur
# Processing Record 45 of Set 1 | stanley
# Processing Record 46 of Set 1 | blackmans bay
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 50 of Set 1 | selfoss
# Processing Record 0 of Set 2 | mossel bay
# Processing Record 1 of Set 2 | curuzu cuatia
# Processing Record 2 of Set 2 | raja
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | junnar
# Processing Record 6 of Set 2 | kariba
# Processing Record 7 of Set 2 | ladario
# Processing Record 8 of Set 2 | college
# Processing Record 9 of Set 2 | port mathurin
# Processing Record 10 of Set 2 | kangding
# Processing Record 11 of Set 2 | kilju
# Processing Record 12 of Set 2 | shenkursk
# Processing Record 13 of Set 2 | ust'-barguzin
# Processing Record 14 of Set 2 | edinburgh of the seven seas
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | saint-raphael
# Processing Record 17 of Set 2 | margaret river
# Processing Record 18 of Set 2 | inekar
# City not found. Skipping...
# Processing Record 19 of Set 2 | west island
# Processing Record 20 of Set 2 | mahina
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | tsiombe
# Processing Record 23 of Set 2 | hammerfest
# Processing Record 24 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 2 | roma
# Processing Record 26 of Set 2 | orrville
# Processing Record 27 of Set 2 | urcos
# Processing Record 28 of Set 2 | holualoa
# Processing Record 29 of Set 2 | namdrik
# Processing Record 30 of Set 2 | takoradi
# Processing Record 31 of Set 2 | san clemente del tuyu
# Processing Record 32 of Set 2 | khulm
# Processing Record 33 of Set 2 | igunga
# Processing Record 34 of Set 2 | davos
# Processing Record 35 of Set 2 | valley east
# City not found. Skipping...
# Processing Record 36 of Set 2 | yelabuga
# Processing Record 37 of Set 2 | sabang
# Processing Record 38 of Set 2 | saipan
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | northam
# Processing Record 41 of Set 2 | longyearbyen
# Processing Record 42 of Set 2 | dryden
# Processing Record 43 of Set 2 | imamoglu
# Processing Record 44 of Set 2 | catriel
# Processing Record 45 of Set 2 | revda
# Processing Record 46 of Set 2 | sovetskaya gavan'
# Processing Record 47 of Set 2 | olonkinbyen
# Processing Record 48 of Set 2 | wailua homesteads
# Processing Record 49 of Set 2 | saratamata
# City not found. Skipping...
# Processing Record 0 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 3 | san patricio
# Processing Record 2 of Set 3 | moose jaw
# Processing Record 3 of Set 3 | merizo village
# Processing Record 4 of Set 3 | ocean pointe
# City not found. Skipping...
# Processing Record 5 of Set 3 | utrik
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | whitehorse
# Processing Record 8 of Set 3 | valparaiso
# Processing Record 9 of Set 3 | kerikeri
# Processing Record 10 of Set 3 | puerto natales
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | keflavik
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | uturoa
# Processing Record 15 of Set 3 | andreyevo
# Processing Record 16 of Set 3 | tura
# Processing Record 17 of Set 3 | rudbar
# Processing Record 18 of Set 3 | masinigudi
# Processing Record 19 of Set 3 | bayan nur
# City not found. Skipping...
# Processing Record 20 of Set 3 | ebon
# Processing Record 21 of Set 3 | colonia
# Processing Record 22 of Set 3 | anadyr
# Processing Record 23 of Set 3 | flying fish cove
# Processing Record 24 of Set 3 | manchester
# Processing Record 25 of Set 3 | east ballina
# Processing Record 26 of Set 3 | quellon
# Processing Record 27 of Set 3 | ulladulla
# Processing Record 28 of Set 3 | kurumkan
# Processing Record 29 of Set 3 | hakui
# Processing Record 30 of Set 3 | papatowai
# Processing Record 31 of Set 3 | puerto colombia
# Processing Record 32 of Set 3 | fale old settlement
# Processing Record 33 of Set 3 | arraias
# Processing Record 34 of Set 3 | pechora
# Processing Record 35 of Set 3 | aykhal
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | gizo
# Processing Record 38 of Set 3 | mbanza-ngungu
# Processing Record 39 of Set 3 | kapuskasing
# Processing Record 40 of Set 3 | bokhan
# Processing Record 41 of Set 3 | st. john's
# Processing Record 42 of Set 3 | nyurba
# Processing Record 43 of Set 3 | sosnovo-ozerskoye
# Processing Record 44 of Set 3 | antsiranana
# Processing Record 45 of Set 3 | lukolela
# Processing Record 46 of Set 3 | shushtar
# Processing Record 47 of Set 3 | progreso
# Processing Record 48 of Set 3 | san julian
# Processing Record 49 of Set 3 | fort bragg
# Processing Record 0 of Set 4 | puerto baquerizo moreno
# Processing Record 1 of Set 4 | aasiaat
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | susuman
# Processing Record 4 of Set 4 | kununurra
# Processing Record 5 of Set 4 | bagneres-de-bigorre
# Processing Record 6 of Set 4 | kiselevsk
# Processing Record 7 of Set 4 | sebezh
# Processing Record 8 of Set 4 | nadi
# Processing Record 9 of Set 4 | midvagur
# Processing Record 10 of Set 4 | princeville
# Processing Record 11 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 12 of Set 4 | borogontsy
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | danjiangkou
# Processing Record 15 of Set 4 | alofi
# Processing Record 16 of Set 4 | mount gambier
# Processing Record 17 of Set 4 | bahia blanca
# Processing Record 18 of Set 4 | bac lieu
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | pandan
# Processing Record 21 of Set 4 | polyarnyy
# Processing Record 22 of Set 4 | lamu
# Processing Record 23 of Set 4 | pariang
# City not found. Skipping...
# Processing Record 24 of Set 4 | suksun
# Processing Record 25 of Set 4 | kismayo
# Processing Record 26 of Set 4 | constantia
# Processing Record 27 of Set 4 | caleta de carquin
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | new norfolk
# Processing Record 30 of Set 4 | klyuchi
# Processing Record 31 of Set 4 | vilhena
# Processing Record 32 of Set 4 | ola
# Processing Record 33 of Set 4 | bandarbeyla
# Processing Record 34 of Set 4 | hirara
# Processing Record 35 of Set 4 | enewetak
# Processing Record 36 of Set 4 | dudinka
# Processing Record 37 of Set 4 | bilibino
# Processing Record 38 of Set 4 | aswan
# Processing Record 39 of Set 4 | grand gaube
# Processing Record 40 of Set 4 | baikonur
# Processing Record 41 of Set 4 | ghat
# Processing Record 42 of Set 4 | nemuro
# Processing Record 43 of Set 4 | puerto plata
# Processing Record 44 of Set 4 | letlhakeng
# Processing Record 45 of Set 4 | crane
# Processing Record 46 of Set 4 | lagos
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | queenstown
# Processing Record 0 of Set 5 | walvis bay
# Processing Record 1 of Set 5 | banda aceh
# Processing Record 2 of Set 5 | arvayheer
# Processing Record 3 of Set 5 | tazovsky
# Processing Record 4 of Set 5 | hanceville
# Processing Record 5 of Set 5 | kingston
# Processing Record 6 of Set 5 | chalus
# Processing Record 7 of Set 5 | alindao
# Processing Record 8 of Set 5 | san antonio de pale
# Processing Record 9 of Set 5 | harper
# Processing Record 10 of Set 5 | connell
# Processing Record 11 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 5 | adrar
# Processing Record 13 of Set 5 | nadym
# Processing Record 14 of Set 5 | visby
# Processing Record 15 of Set 5 | sorong
# Processing Record 16 of Set 5 | mogadishu
# Processing Record 17 of Set 5 | kuqa
# Processing Record 18 of Set 5 | boa vista
# Processing Record 19 of Set 5 | karratha
# Processing Record 20 of Set 5 | puerto leguizamo
# Processing Record 21 of Set 5 | mirabad
# Processing Record 22 of Set 5 | hermanus
# Processing Record 23 of Set 5 | saint-pierre
# Processing Record 24 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 25 of Set 5 | kapa'a
# Processing Record 26 of Set 5 | port saint john's
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | perugorria
# Processing Record 29 of Set 5 | al ghayzah
# Processing Record 30 of Set 5 | punta arenas
# Processing Record 31 of Set 5 | cole harbour
# Processing Record 32 of Set 5 | pyhajarvi
# Processing Record 33 of Set 5 | vadso
# Processing Record 34 of Set 5 | kuloy
# Processing Record 35 of Set 5 | wesley
# Processing Record 36 of Set 5 | vorgashor
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | lihue
# Processing Record 39 of Set 5 | nova vicosa
# Processing Record 40 of Set 5 | lubang
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | hampton bays
# Processing Record 43 of Set 5 | omutinskiy
# Processing Record 44 of Set 5 | tuchow
# Processing Record 45 of Set 5 | villamontes
# Processing Record 46 of Set 5 | es castell
# Processing Record 47 of Set 5 | tahe
# Processing Record 48 of Set 5 | san diego country estates
# Processing Record 49 of Set 5 | balakhta
# Processing Record 0 of Set 6 | astrakhan
# Processing Record 1 of Set 6 | vila velha
# Processing Record 2 of Set 6 | machico
# Processing Record 3 of Set 6 | saint-philippe
# Processing Record 4 of Set 6 | maceio
# Processing Record 5 of Set 6 | arkhangel'sk
# Processing Record 6 of Set 6 | banes
# Processing Record 7 of Set 6 | zaokskiy
# Processing Record 8 of Set 6 | hamilton
# Processing Record 9 of Set 6 | beberibe
# Processing Record 10 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 11 of Set 6 | i-n-salah
# Processing Record 12 of Set 6 | rongelap
# Processing Record 13 of Set 6 | laojunmiao
# Processing Record 14 of Set 6 | egilsstadir
# Processing Record 15 of Set 6 | afaahiti
# Processing Record 16 of Set 6 | tual
# Processing Record 17 of Set 6 | carutapera
# Processing Record 18 of Set 6 | gorleston-on-sea
# Processing Record 19 of Set 6 | bereznik
# Processing Record 20 of Set 6 | badger
# Processing Record 21 of Set 6 | iquique
# Processing Record 22 of Set 6 | haiku-pauwela
# Processing Record 23 of Set 6 | oranjemund
# Processing Record 24 of Set 6 | rio grande
# Processing Record 25 of Set 6 | dubovka
# Processing Record 26 of Set 6 | mexico
# Processing Record 27 of Set 6 | eenhana
# Processing Record 28 of Set 6 | woodstock
# Processing Record 29 of Set 6 | yuzhno-kurilsk
# Processing Record 30 of Set 6 | arraial do cabo
# Processing Record 31 of Set 6 | kandira
# Processing Record 32 of Set 6 | calvinia
# Processing Record 33 of Set 6 | bouar
# Processing Record 34 of Set 6 | el granada
# Processing Record 35 of Set 6 | luimneach
# Processing Record 36 of Set 6 | viedma
# Processing Record 37 of Set 6 | sao paulo de olivenca
# Processing Record 38 of Set 6 | zakamensk
# Processing Record 39 of Set 6 | rio preto da eva
# Processing Record 40 of Set 6 | udachny
# Processing Record 41 of Set 6 | crescentino
# Processing Record 42 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 43 of Set 6 | alliance
# Processing Record 44 of Set 6 | hami
# Processing Record 45 of Set 6 | tanki leendert
# City not found. Skipping...
# Processing Record 46 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 6 | ain bessem
# Processing Record 48 of Set 6 | nicoya
# Processing Record 49 of Set 6 | kibre mengist
# Processing Record 0 of Set 7 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 1 of Set 7 | moirang
# Processing Record 2 of Set 7 | kapit
# Processing Record 3 of Set 7 | emerald
# Processing Record 4 of Set 7 | cotonou
# Processing Record 5 of Set 7 | santa vitoria do palmar
# Processing Record 6 of Set 7 | el gouna
# Processing Record 7 of Set 7 | kiknur
# Processing Record 8 of Set 7 | as sulayyil
# Processing Record 9 of Set 7 | arish
# Processing Record 10 of Set 7 | ilhabela
# Processing Record 11 of Set 7 | beira
# Processing Record 12 of Set 7 | incline village
# Processing Record 13 of Set 7 | xai-xai
# Processing Record 14 of Set 7 | atafu village
# Processing Record 15 of Set 7 | chibougamau
# Processing Record 16 of Set 7 | lazaro cardenas
# Processing Record 17 of Set 7 | westport
# Processing Record 18 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 19 of Set 7 | saldanha
# Processing Record 20 of Set 7 | egirdir
# Processing Record 21 of Set 7 | la passe
# Processing Record 22 of Set 7 | sanctuary point
# Processing Record 23 of Set 7 | remire-montjoly
# Processing Record 24 of Set 7 | kasane
# Processing Record 25 of Set 7 | samarinda
# Processing Record 26 of Set 7 | vernon
# Processing Record 27 of Set 7 | okhotsk
# Processing Record 28 of Set 7 | hithadhoo
# Processing Record 29 of Set 7 | mejit
# Processing Record 30 of Set 7 | elmendorf air force base
# City not found. Skipping...
# Processing Record 31 of Set 7 | nishinoomote
# Processing Record 32 of Set 7 | luau
# Processing Record 33 of Set 7 | lata
# Processing Record 34 of Set 7 | iskateley
# Processing Record 35 of Set 7 | glace bay
# Processing Record 36 of Set 7 | almazan
# Processing Record 37 of Set 7 | ha'il
# Processing Record 38 of Set 7 | kol'chugino
# Processing Record 39 of Set 7 | bornu yassu
# Processing Record 40 of Set 7 | freetown
# Processing Record 41 of Set 7 | gray
# Processing Record 42 of Set 7 | limbang
# Processing Record 43 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 44 of Set 7 | qinzhou
# Processing Record 45 of Set 7 | sumenep
# Processing Record 46 of Set 7 | les avirons
# Processing Record 47 of Set 7 | ulanhot
# Processing Record 48 of Set 7 | oyama
# Processing Record 49 of Set 7 | gamba
# Processing Record 0 of Set 8 | kasama
# Processing Record 1 of Set 8 | pionerskiy
# Processing Record 2 of Set 8 | goure
# Processing Record 3 of Set 8 | tete
# Processing Record 4 of Set 8 | port glaud
# City not found. Skipping...
# Processing Record 5 of Set 8 | luwingu
# Processing Record 6 of Set 8 | palm beach
# Processing Record 7 of Set 8 | sungai penuh
# Processing Record 8 of Set 8 | petrozavodsk
# Processing Record 9 of Set 8 | troitsko-pechorsk
# Processing Record 10 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 11 of Set 8 | porbandar
# Processing Record 12 of Set 8 | las varas
# Processing Record 13 of Set 8 | acatlan de osorio
# Processing Record 14 of Set 8 | esfarayen
# Processing Record 15 of Set 8 | macheng
# Processing Record 16 of Set 8 | san jose del guaviare
# Processing Record 17 of Set 8 | nuku'alofa
# Processing Record 18 of Set 8 | rampur
# Processing Record 19 of Set 8 | willowmore
# Processing Record 20 of Set 8 | coahuayana de hidalgo
# Processing Record 21 of Set 8 | hadibu
# Processing Record 22 of Set 8 | skopin
# Processing Record 23 of Set 8 | east stroudsburg
# Processing Record 24 of Set 8 | nuuk
# Processing Record 25 of Set 8 | iskushuban
# Processing Record 26 of Set 8 | suda
# Processing Record 27 of Set 8 | bodo
# Processing Record 28 of Set 8 | zhosaly
# Processing Record 29 of Set 8 | uirauna
# Processing Record 30 of Set 8 | steinbach
# Processing Record 31 of Set 8 | prince rupert
# Processing Record 32 of Set 8 | hastings
# Processing Record 33 of Set 8 | paramonga
# Processing Record 34 of Set 8 | chonchi
# Processing Record 35 of Set 8 | lycksele
# Processing Record 36 of Set 8 | gressier
# Processing Record 37 of Set 8 | bhattarai danda
# Processing Record 38 of Set 8 | san jose village
# City not found. Skipping...
# Processing Record 39 of Set 8 | san pedro
# Processing Record 40 of Set 8 | tofol
# Processing Record 41 of Set 8 | gadzhiyevo
# Processing Record 42 of Set 8 | bamboo flat
# Processing Record 43 of Set 8 | cabaritan east
# Processing Record 44 of Set 8 | garachico
# Processing Record 45 of Set 8 | lhasa
# Processing Record 46 of Set 8 | launceston
# Processing Record 47 of Set 8 | senillosa
# Processing Record 48 of Set 8 | kavaratti
# Processing Record 49 of Set 8 | kamina
# Processing Record 0 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 1 of Set 9 | mogocha
# Processing Record 2 of Set 9 | alice springs
# Processing Record 3 of Set 9 | vuktyl
# Processing Record 4 of Set 9 | kayangel
# Processing Record 5 of Set 9 | tanggu
# Processing Record 6 of Set 9 | orenburg
# Processing Record 7 of Set 9 | ingeniero jacobacci
# Processing Record 8 of Set 9 | duba
# Processing Record 9 of Set 9 | amungan
# Processing Record 10 of Set 9 | mareeba
# Processing Record 11 of Set 9 | robore
# Processing Record 12 of Set 9 | nova sintra
# Processing Record 13 of Set 9 | bilajer
# Processing Record 14 of Set 9 | tutoia
# Processing Record 15 of Set 9 | feijo
# Processing Record 16 of Set 9 | kone
# Processing Record 17 of Set 9 | tolanaro
# Processing Record 18 of Set 9 | shannon
# Processing Record 19 of Set 9 | mil'kovo
# Processing Record 20 of Set 9 | nguigmi
# Processing Record 21 of Set 9 | eraan
# Processing Record 22 of Set 9 | beni
# Processing Record 23 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 24 of Set 9 | miyanoura
# City not found. Skipping...
# Processing Record 25 of Set 9 | kamuli
# Processing Record 26 of Set 9 | shahabad
# Processing Record 27 of Set 9 | miramichi
# Processing Record 28 of Set 9 | callao
# Processing Record 29 of Set 9 | thohoyandou
# Processing Record 30 of Set 9 | kandyagash
# Processing Record 31 of Set 9 | brak
# Processing Record 32 of Set 9 | dara
# Processing Record 33 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 34 of Set 9 | bonnyville
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | puerto san jose
# Processing Record 37 of Set 9 | najran
# Processing Record 38 of Set 9 | sitka
# Processing Record 39 of Set 9 | pierre
# Processing Record 40 of Set 9 | kita
# Processing Record 41 of Set 9 | faranah
# Processing Record 42 of Set 9 | longmen
# Processing Record 43 of Set 9 | basco
# Processing Record 44 of Set 9 | dellys
# Processing Record 45 of Set 9 | santana
# Processing Record 46 of Set 9 | axim
# Processing Record 47 of Set 9 | joaquin v. gonzalez
# Processing Record 48 of Set 9 | mantsala
# Processing Record 49 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 0 of Set 10 | grantsville
# Processing Record 1 of Set 10 | farafangana
# Processing Record 2 of Set 10 | inari
# Processing Record 3 of Set 10 | fort mcmurray
# Processing Record 4 of Set 10 | bafra
# Processing Record 5 of Set 10 | dolisie
# Processing Record 6 of Set 10 | inhambane
# Processing Record 7 of Set 10 | fort st. john
# Processing Record 8 of Set 10 | tulagi
# Processing Record 9 of Set 10 | byron bay
# Processing Record 10 of Set 10 | waingapu
# Processing Record 11 of Set 10 | unai
# Processing Record 12 of Set 10 | dikhil
# Processing Record 13 of Set 10 | smara
# Processing Record 14 of Set 10 | tra mhor
# Processing Record 15 of Set 10 | cruz do espirito santo
# Processing Record 16 of Set 10 | port douglas
# Processing Record 17 of Set 10 | dhidhdhoo
# Processing Record 18 of Set 10 | bardai
# Processing Record 19 of Set 10 | fada n'gourma
# Processing Record 20 of Set 10 | kaiyuan
# Processing Record 21 of Set 10 | murehwa
# Processing Record 22 of Set 10 | san luis
# Processing Record 23 of Set 10 | santa cruz
# Processing Record 24 of Set 10 | labasa
# Processing Record 25 of Set 10 | rawson
# Processing Record 26 of Set 10 | corner brook
# Processing Record 27 of Set 10 | roxborough park
# Processing Record 28 of Set 10 | sisophon
# Processing Record 29 of Set 10 | weno
# Processing Record 30 of Set 10 | baardheere
# Processing Record 31 of Set 10 | edson
# Processing Record 32 of Set 10 | san juan del sur
# Processing Record 33 of Set 10 | ormara
# Processing Record 34 of Set 10 | chimore
# Processing Record 35 of Set 10 | varzea grande
# Processing Record 36 of Set 10 | rio verde
# Processing Record 37 of Set 10 | antipolo
# Processing Record 38 of Set 10 | khandud
# Processing Record 39 of Set 10 | saudarkrokur
# Processing Record 40 of Set 10 | mana
# Processing Record 41 of Set 10 | chaparral
# Processing Record 42 of Set 10 | idri
# Processing Record 43 of Set 10 | santa flavia
# Processing Record 44 of Set 10 | wahpeton
# Processing Record 45 of Set 10 | kabalo
# Processing Record 46 of Set 10 | bel ombre
# Processing Record 47 of Set 10 | chhor
# Processing Record 48 of Set 10 | xinyuan
# Processing Record 49 of Set 10 | brod
# Processing Record 0 of Set 11 | sinop
# Processing Record 1 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 2 of Set 11 | staritsa
# Processing Record 3 of Set 11 | priob'ye
# Processing Record 4 of Set 11 | waterford
# Processing Record 5 of Set 11 | falam
# Processing Record 6 of Set 11 | kish
# Processing Record 7 of Set 11 | sofifi
# City not found. Skipping...
# Processing Record 8 of Set 11 | papao
# Processing Record 9 of Set 11 | barah
# Processing Record 10 of Set 11 | kiuruvesi
# Processing Record 11 of Set 11 | antofagasta
# Processing Record 12 of Set 11 | greenville
# Processing Record 13 of Set 11 | hazorasp
# Processing Record 14 of Set 11 | gulf shores
# Processing Record 15 of Set 11 | happy valley-goose bay
# Processing Record 16 of Set 11 | tarakan
# Processing Record 17 of Set 11 | nguruka
# Processing Record 18 of Set 11 | sao vicente
# Processing Record 19 of Set 11 | hasaki
# Processing Record 20 of Set 11 | vila franca do campo
# Processing Record 21 of Set 11 | klerksdorp
# Processing Record 22 of Set 11 | kenora
# Processing Record 23 of Set 11 | san juan del rio
# Processing Record 24 of Set 11 | mutsu
# Processing Record 25 of Set 11 | concepcion del oro
# Processing Record 26 of Set 11 | guerrero negro
# Processing Record 27 of Set 11 | khasab
# Processing Record 28 of Set 11 | acapulco de juarez
# Processing Record 29 of Set 11 | cabo san lucas
# Processing Record 30 of Set 11 | ambato boeny
# Processing Record 31 of Set 11 | fuerte olimpo
# Processing Record 32 of Set 11 | saguenay
# Processing Record 33 of Set 11 | skuodas
# Processing Record 34 of Set 11 | tumayr
# Processing Record 35 of Set 11 | broken hill
# Processing Record 36 of Set 11 | tamanrasset
# Processing Record 37 of Set 11 | abaetetuba
# Processing Record 38 of Set 11 | onega
# Processing Record 39 of Set 11 | gamay
# Processing Record 40 of Set 11 | madingou
# Processing Record 41 of Set 11 | villa rica
# Processing Record 42 of Set 11 | mthatha
# Processing Record 43 of Set 11 | tagiura
# Processing Record 44 of Set 11 | nizhniy odes
# Processing Record 45 of Set 11 | cam ranh
# Processing Record 46 of Set 11 | meijel
# Processing Record 47 of Set 11 | buala
# Processing Record 48 of Set 11 | borgarnes
# Processing Record 49 of Set 11 | portland
# Processing Record 0 of Set 12 | mount pearl
# Processing Record 1 of Set 12 | chengde
# Processing Record 2 of Set 12 | sidi khaled
# Processing Record 3 of Set 12 | rouissat
# Processing Record 4 of Set 12 | bueng kan
# Processing Record 5 of Set 12 | ishigaki
# Processing Record 6 of Set 12 | san roque
# Processing Record 7 of Set 12 | namtsy
# Processing Record 8 of Set 12 | skovorodino
# Processing Record 9 of Set 12 | salina cruz
# Processing Record 10 of Set 12 | opuwo
# Processing Record 11 of Set 12 | castillos
# Processing Record 12 of Set 12 | ippy
# Processing Record 13 of Set 12 | lignano sabbiadoro
# Processing Record 14 of Set 12 | amol
# Processing Record 15 of Set 12 | barra de santo antonio
# Processing Record 16 of Set 12 | olingan
# Processing Record 17 of Set 12 | ambodifotatra
# Processing Record 18 of Set 12 | yongchuan
# Processing Record 19 of Set 12 | rabaul
# Processing Record 20 of Set 12 | sebin karahisar
# Processing Record 21 of Set 12 | dzhalagash
# Processing Record 22 of Set 12 | yangjiang
# Processing Record 23 of Set 12 | ermoupolis
# Processing Record 24 of Set 12 | kolondieba
# Processing Record 25 of Set 12 | wanxian
# Processing Record 26 of Set 12 | santa elena de uairen
# Processing Record 27 of Set 12 | kingscliff
# Processing Record 28 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 29 of Set 12 | hotan
# Processing Record 30 of Set 12 | geraldton
# Processing Record 31 of Set 12 | kshenskiy
# Processing Record 32 of Set 12 | akureyri
# Processing Record 33 of Set 12 | tselinnoye
# Processing Record 34 of Set 12 | sisimiut
# Processing Record 35 of Set 12 | arar
# Processing Record 36 of Set 12 | shahrak-e pabedana
# City not found. Skipping...
# Processing Record 37 of Set 12 | langepas
# Processing Record 38 of Set 12 | sarangani
# Processing Record 39 of Set 12 | la charite-sur-loire
# Processing Record 40 of Set 12 | himimachi
# Processing Record 41 of Set 12 | istgah-e rah ahan-e garmsar
# Processing Record 42 of Set 12 | ebeltoft
# Processing Record 43 of Set 12 | maragogi
# Processing Record 44 of Set 12 | loch garman
# Processing Record 45 of Set 12 | soro
# Processing Record 46 of Set 12 | bhimunipatnam
# Processing Record 47 of Set 12 | rexburg
# Processing Record 48 of Set 12 | pauini
# Processing Record 49 of Set 12 | sao jose da coroa grande
# Processing Record 0 of Set 13 | tabou
# Processing Record 1 of Set 13 | acarau
# Processing Record 2 of Set 13 | shanhaiguan
# Processing Record 3 of Set 13 | bandar-e lengeh
# Processing Record 4 of Set 13 | greenbrier
# Processing Record 5 of Set 13 | linhares
# Processing Record 6 of Set 13 | kzyltu
# Processing Record 7 of Set 13 | palmer
# Processing Record 8 of Set 13 | champerico
# Processing Record 9 of Set 13 | bratsk
# Processing Record 10 of Set 13 | belmonte
# Processing Record 11 of Set 13 | fortuna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        yellowknife  62.4560 -114.3525     -5.71        61          20
# 1  torre de moncorvo  41.1792   -7.0358      6.51        90          92
# 2         codrington -38.2667  141.9667     15.12        50          79
# 3            kajiado  -1.8524   36.7768     15.69        97         100
# 4           waitangi -43.9535 -176.5597     11.01        74          45
#
#    Wind Speed Country        Date
# 0        2.06      CA  1714188651
# 1        0.89      PT  1714188802
# 2        2.12      AU  1714188803
# 3        2.13      KE  1714188803
# 4        3.13      NZ  1714188803

# %%
# Export the City_Data into a csv
from pathlib import Path  
filepath = Path('python-api-challenge/output_data/cities.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)       
city_data_df.to_csv("python-api-challenge/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("python-api-challenge/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              yellowknife  62.4560 -114.3525     -5.71        61          20
# 1        torre de moncorvo  41.1792   -7.0358      6.51        90          92
# 2               codrington -38.2667  141.9667     15.12        50          79
# 3                  kajiado  -1.8524   36.7768     15.69        97         100
# 4                 waitangi -43.9535 -176.5597     11.01        74          45
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      CA  1714188651
# 1              0.89      PT  1714188802
# 2              2.12      AU  1714188803
# 3              2.13      KE  1714188803
# 4              3.13      NZ  1714188803

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
temp = city_data_df['Max Temp']

x = latitude
y = temp
plt.scatter(x, y, edgecolors='black')
plt.title('City Max Latitude vs. Temperature (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
humidity = city_data_df['Humidity']
x = latitude
y = humidity
plt.scatter(x,y,edgecolors='black')
plt.title('City Max Latitude vs. Humidity (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']
x = latitude
y = cloudiness
plt.scatter(x,y,edgecolors='black')
plt.title('City Max Latitude vs. Humidity (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
wind_speed = city_data_df['Wind Speed']
x = latitude
y = wind_speed
plt.scatter(x,y,edgecolors='black')
plt.title('City Max Latitude vs. Humidity (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values, marker="o", color="skyblue", edgecolors="black")
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(min(x_values),min(y_values)),fontsize=20,color="red")
    plt.xlabel('Latitude')
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              yellowknife  62.4560 -114.3525     -5.71        61          20
# 1        torre de moncorvo  41.1792   -7.0358      6.51        90          92
# 5                 qaqortoq  60.7167  -46.0333     -0.17        94          95
# 7                   razole  16.4833   81.8333     35.88        41          54
# 8              vilyuchinsk  52.9306  158.4028      3.15        99         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      CA  1714188651
# 1              0.89      PT  1714188802
# 5              3.21      GL  1714188803
# 7              2.75      IN  1714188803
# 8              0.85      RU  1714188803

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] <=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2               codrington -38.2667  141.9667     15.12        50          79
# 3                  kajiado  -1.8524   36.7768     15.69        97         100
# 4                 waitangi -43.9535 -176.5597     11.01        74          45
# 6             invercargill -46.4000  168.3500     11.68        96         100
# 11       port-aux-francais -49.3500   70.2167      7.01        97         100
#
#          Wind Speed Country        Date
# City_ID
# 2              2.12      AU  1714188803
# 3              2.13      KE  1714188803
# 4              3.13      NZ  1714188803
# 6              6.26      NZ  1714188803
# 11            11.05      TF  1714188803

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Max Temperature (2024-04-26)")
plt.ylabel("Max Temperature")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.7585234057821786

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Max Temperature (2024-04-26)")
plt.ylabel("Max Temperature")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.47368402046401403

# %% [markdown]
# **Discussion about the linear relationship:** Temperatures are higher in cities located closer to the equator (0) and temperatures are lower in cities located further away from the equator. This trend is observed in both the norther and southern hemispheres.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Humidity (2024-04-26)")
plt.ylabel("Humidity")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.048106937955102576

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Humidity (2024-04-26)")
plt.ylabel("Humidity")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.06757946905620081

# %% [markdown]
# **Discussion about the linear relationship:** Humidity rises the further a city is located from the equator (0) in the northern hemisphere. Humidity lowers the further a city is located from the equator in the souther hemisphere. There is no observable correlation in this trend.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Cloudiness (2024-04-26)")
plt.ylabel("Cloudiness")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.024911011731535194

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Cloudiness (2024-04-26)")
plt.ylabel("Cloudiness")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.06050546971346259

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness is roughly equal in both the northern and southern hemispheres. A greater number of cities in the northern hemisphere fall along the slope of the line.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Windiness (2024-04-26)")
plt.ylabel("Wind Speed")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.004769571998424983

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Windiness (2024-04-26)")
plt.ylabel("Wind Speed")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.08430311798281599

# %% [markdown]
# **Discussion about the linear relationship:** Windiness is quite consistent in the northern hemisphere. Windiness picked up sharply in cities further away from the equator (0) in the southern hemisphere.
