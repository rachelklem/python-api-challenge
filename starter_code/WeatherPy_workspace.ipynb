# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}appid={weather_api_key}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | kamthi
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | constantia
# Processing Record 5 of Set 1 | papatowai
# Processing Record 6 of Set 1 | vadso
# Processing Record 7 of Set 1 | palpa
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | bikenibeu village
# Processing Record 10 of Set 1 | stanley
# Processing Record 11 of Set 1 | vrangel'
# Processing Record 12 of Set 1 | edinburgh of the seven seas
# Processing Record 13 of Set 1 | hobyo
# Processing Record 14 of Set 1 | st. john's
# Processing Record 15 of Set 1 | whitehorse
# Processing Record 16 of Set 1 | west island
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | lokomotivnyy
# Processing Record 19 of Set 1 | al qusayr
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | vernal
# Processing Record 23 of Set 1 | blackmans bay
# Processing Record 24 of Set 1 | qaqortoq
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | greymouth
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | port-aux-francais
# Processing Record 29 of Set 1 | kimbe
# Processing Record 30 of Set 1 | la'ie
# Processing Record 31 of Set 1 | waitangi
# Processing Record 32 of Set 1 | tazovsky
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | itoman
# Processing Record 35 of Set 1 | chibougamau
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | susuman
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | kingston
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | swakopmund
# Processing Record 43 of Set 1 | puerto natales
# Processing Record 44 of Set 1 | sao joao do piaui
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | port augusta
# Processing Record 47 of Set 1 | tura
# Processing Record 48 of Set 1 | nuuk
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 50 of Set 1 | dame-marie
# Processing Record 0 of Set 2 | corner brook
# Processing Record 1 of Set 2 | nuevitas
# Processing Record 2 of Set 2 | afaahiti
# Processing Record 3 of Set 2 | amursk
# Processing Record 4 of Set 2 | isafjordur
# Processing Record 5 of Set 2 | leava
# Processing Record 6 of Set 2 | zheleznodorozhnyy
# Processing Record 7 of Set 2 | beteza
# City not found. Skipping...
# Processing Record 8 of Set 2 | hutto
# Processing Record 9 of Set 2 | tbeng meanchey
# Processing Record 10 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 2 | banda aceh
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | veitsbronn
# Processing Record 14 of Set 2 | invercargill
# Processing Record 15 of Set 2 | manjeri
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | lompoc
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | yinzhu
# Processing Record 20 of Set 2 | aasiaat
# Processing Record 21 of Set 2 | hastings
# Processing Record 22 of Set 2 | dudinka
# Processing Record 23 of Set 2 | ust'-ilimsk
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | kuching
# Processing Record 26 of Set 2 | darnah
# Processing Record 27 of Set 2 | arar
# Processing Record 28 of Set 2 | bilibino
# Processing Record 29 of Set 2 | chonchi
# Processing Record 30 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 31 of Set 2 | klyuchi
# Processing Record 32 of Set 2 | smara
# Processing Record 33 of Set 2 | mangrol
# Processing Record 34 of Set 2 | chicoana
# Processing Record 35 of Set 2 | conde
# Processing Record 36 of Set 2 | pervomayskoye
# Processing Record 37 of Set 2 | maceio
# Processing Record 38 of Set 2 | taoudenni
# Processing Record 39 of Set 2 | vernon
# Processing Record 40 of Set 2 | zhuhai
# Processing Record 41 of Set 2 | bagaha
# Processing Record 42 of Set 2 | kirkwood
# Processing Record 43 of Set 2 | saudarkrokur
# Processing Record 44 of Set 2 | la sarre
# Processing Record 45 of Set 2 | tobruk
# Processing Record 46 of Set 2 | minab
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | tanah merah
# Processing Record 49 of Set 2 | kas
# Processing Record 0 of Set 3 | port moresby
# Processing Record 1 of Set 3 | caleta de carquin
# Processing Record 2 of Set 3 | utrik
# Processing Record 3 of Set 3 | ouellah
# City not found. Skipping...
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | mhamid
# Processing Record 6 of Set 3 | egilsstadir
# Processing Record 7 of Set 3 | happy valley-goose bay
# Processing Record 8 of Set 3 | hudiksvall
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | olonkinbyen
# Processing Record 11 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 3 | waingapu
# Processing Record 13 of Set 3 | vuktyl
# Processing Record 14 of Set 3 | cape canaveral
# Processing Record 15 of Set 3 | vilyuysk
# Processing Record 16 of Set 3 | bandrele
# Processing Record 17 of Set 3 | severo-yeniseyskiy
# Processing Record 18 of Set 3 | margaret river
# Processing Record 19 of Set 3 | fier
# Processing Record 20 of Set 3 | punta arenas
# Processing Record 21 of Set 3 | badger
# Processing Record 22 of Set 3 | college
# Processing Record 23 of Set 3 | namsos
# Processing Record 24 of Set 3 | iskateley
# Processing Record 25 of Set 3 | kolyshley
# Processing Record 26 of Set 3 | brezina
# Processing Record 27 of Set 3 | zhezqazghan
# Processing Record 28 of Set 3 | sisimiut
# Processing Record 29 of Set 3 | villa bruzual
# Processing Record 30 of Set 3 | ketchikan
# Processing Record 31 of Set 3 | hafar al-batin
# Processing Record 32 of Set 3 | orsta
# Processing Record 33 of Set 3 | sinabang
# Processing Record 34 of Set 3 | astorga
# Processing Record 35 of Set 3 | yinchuan
# Processing Record 36 of Set 3 | tadine
# Processing Record 37 of Set 3 | paraiso
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | bredasdorp
# Processing Record 41 of Set 3 | polyarnyy
# Processing Record 42 of Set 3 | oltinko'l
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | san jeronimo de juarez
# Processing Record 45 of Set 3 | lang suan
# Processing Record 46 of Set 3 | pacific grove
# Processing Record 47 of Set 3 | thunder bay
# Processing Record 48 of Set 3 | rawai
# Processing Record 49 of Set 3 | hamilton
# Processing Record 0 of Set 4 | machico
# Processing Record 1 of Set 4 | usogorsk
# Processing Record 2 of Set 4 | mulayjah
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | hawaiian paradise park
# Processing Record 5 of Set 4 | la libertad
# Processing Record 6 of Set 4 | tobol
# Processing Record 7 of Set 4 | alofi
# Processing Record 8 of Set 4 | vanimo
# Processing Record 9 of Set 4 | gadzhiyevo
# Processing Record 10 of Set 4 | vorgashor
# Processing Record 11 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 12 of Set 4 | dongola
# Processing Record 13 of Set 4 | nyala
# Processing Record 14 of Set 4 | shagonar
# Processing Record 15 of Set 4 | tete
# Processing Record 16 of Set 4 | metlili chaamba
# Processing Record 17 of Set 4 | bandon
# Processing Record 18 of Set 4 | ar ruways
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | arno
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | nabire
# Processing Record 24 of Set 4 | brasileia
# Processing Record 25 of Set 4 | labrador city
# Processing Record 26 of Set 4 | kone
# Processing Record 27 of Set 4 | monrovia
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | dongyang
# Processing Record 30 of Set 4 | preobrazheniye
# Processing Record 31 of Set 4 | imbituba
# Processing Record 32 of Set 4 | nadym
# Processing Record 33 of Set 4 | anadyr
# Processing Record 34 of Set 4 | hilo
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | nouadhibou
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | nagqu
# Processing Record 39 of Set 4 | tateyama
# Processing Record 40 of Set 4 | verkhnevilyuysk
# Processing Record 41 of Set 4 | sishilichengzi
# City not found. Skipping...
# Processing Record 42 of Set 4 | talara
# Processing Record 43 of Set 4 | nakskov
# Processing Record 44 of Set 4 | tual
# Processing Record 45 of Set 4 | christchurch
# Processing Record 46 of Set 4 | ola
# Processing Record 47 of Set 4 | kalaleh
# Processing Record 48 of Set 4 | shindand
# Processing Record 49 of Set 4 | carutapera
# Processing Record 0 of Set 5 | ban tak
# Processing Record 1 of Set 5 | dwarka
# Processing Record 2 of Set 5 | port mathurin
# Processing Record 3 of Set 5 | maumere
# Processing Record 4 of Set 5 | porto murtinho
# Processing Record 5 of Set 5 | coxim
# Processing Record 6 of Set 5 | gorom-gorom
# Processing Record 7 of Set 5 | gubkinskiy
# Processing Record 8 of Set 5 | aykhal
# Processing Record 9 of Set 5 | portoferraio
# Processing Record 10 of Set 5 | zhangjiakou shi xuanhua qu
# Processing Record 11 of Set 5 | siuna
# Processing Record 12 of Set 5 | song cau
# Processing Record 13 of Set 5 | yoko
# Processing Record 14 of Set 5 | tuy hoa
# Processing Record 15 of Set 5 | nova olinda do norte
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | port elizabeth
# Processing Record 18 of Set 5 | kayyerkan
# Processing Record 19 of Set 5 | brazzaville
# Processing Record 20 of Set 5 | cockburn town
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | abou el hassan
# Processing Record 23 of Set 5 | suva
# Processing Record 24 of Set 5 | namibe
# Processing Record 25 of Set 5 | balabac
# Processing Record 26 of Set 5 | weno
# Processing Record 27 of Set 5 | ribadeo
# Processing Record 28 of Set 5 | bardai
# Processing Record 29 of Set 5 | avarua
# Processing Record 30 of Set 5 | ambositra
# Processing Record 31 of Set 5 | lagrange
# Processing Record 32 of Set 5 | wailua homesteads
# Processing Record 33 of Set 5 | mukachevo
# Processing Record 34 of Set 5 | tsiombe
# Processing Record 35 of Set 5 | nar'yan-mar
# Processing Record 36 of Set 5 | wigton
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | lovington
# Processing Record 39 of Set 5 | tilisarao
# Processing Record 40 of Set 5 | el porvenir
# Processing Record 41 of Set 5 | kijang
# Processing Record 42 of Set 5 | dryden
# Processing Record 43 of Set 5 | hassi messaoud
# Processing Record 44 of Set 5 | krasnokholmskiy
# Processing Record 45 of Set 5 | emmett
# Processing Record 46 of Set 5 | prince rupert
# Processing Record 47 of Set 5 | blacksburg
# Processing Record 48 of Set 5 | rongelap
# Processing Record 49 of Set 5 | itaituba
# Processing Record 0 of Set 6 | qulsary
# Processing Record 1 of Set 6 | haiku-pauwela
# Processing Record 2 of Set 6 | khovd
# Processing Record 3 of Set 6 | nemuro
# Processing Record 4 of Set 6 | codrington
# Processing Record 5 of Set 6 | tamandare
# Processing Record 6 of Set 6 | twon-brass
# Processing Record 7 of Set 6 | najafgarh
# Processing Record 8 of Set 6 | kill devil hills
# Processing Record 9 of Set 6 | nogliki
# Processing Record 10 of Set 6 | lucea
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | sarikei
# Processing Record 13 of Set 6 | udachny
# Processing Record 14 of Set 6 | san juan de miraflores
# Processing Record 15 of Set 6 | bukama
# Processing Record 16 of Set 6 | bonthe
# Processing Record 17 of Set 6 | minas de marcona
# Processing Record 18 of Set 6 | jinchang
# Processing Record 19 of Set 6 | port lincoln
# Processing Record 20 of Set 6 | nova vicosa
# Processing Record 21 of Set 6 | natore
# City not found. Skipping...
# Processing Record 22 of Set 6 | kapa'a
# Processing Record 23 of Set 6 | urumqi
# Processing Record 24 of Set 6 | evinayong
# Processing Record 25 of Set 6 | enewetak
# Processing Record 26 of Set 6 | tolanaro
# Processing Record 27 of Set 6 | odobesti
# Processing Record 28 of Set 6 | shubarshi
# Processing Record 29 of Set 6 | george town
# Processing Record 30 of Set 6 | tongouson
# Processing Record 31 of Set 6 | atafu village
# Processing Record 32 of Set 6 | mount gambier
# Processing Record 33 of Set 6 | kalispell
# Processing Record 34 of Set 6 | mount isa
# Processing Record 35 of Set 6 | nizhneudinsk
# Processing Record 36 of Set 6 | ghazni
# Processing Record 37 of Set 6 | maragogi
# Processing Record 38 of Set 6 | sainte-menehould
# Processing Record 39 of Set 6 | hadibu
# Processing Record 40 of Set 6 | mugia
# Processing Record 41 of Set 6 | remire-montjoly
# Processing Record 42 of Set 6 | donduseni
# Processing Record 43 of Set 6 | cidreira
# Processing Record 44 of Set 6 | charles city
# Processing Record 45 of Set 6 | salekhard
# Processing Record 46 of Set 6 | springbok
# Processing Record 47 of Set 6 | stjordalshalsen
# Processing Record 48 of Set 6 | qarqin
# Processing Record 49 of Set 6 | tommot
# Processing Record 0 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 1 of Set 7 | rio grande
# Processing Record 2 of Set 7 | langsa
# Processing Record 3 of Set 7 | coahuayana de hidalgo
# Processing Record 4 of Set 7 | taroa
# Processing Record 5 of Set 7 | villa ojo de agua
# Processing Record 6 of Set 7 | iquitos
# Processing Record 7 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 8 of Set 7 | sakaiminato
# Processing Record 9 of Set 7 | 'ain el melh
# Processing Record 10 of Set 7 | port saint john's
# Processing Record 11 of Set 7 | cold springs
# Processing Record 12 of Set 7 | shalkar
# Processing Record 13 of Set 7 | san rafael
# Processing Record 14 of Set 7 | anloga
# Processing Record 15 of Set 7 | zouerate
# Processing Record 16 of Set 7 | ape
# Processing Record 17 of Set 7 | santana
# Processing Record 18 of Set 7 | margate
# Processing Record 19 of Set 7 | dowa
# Processing Record 20 of Set 7 | nuku'alofa
# Processing Record 21 of Set 7 | ust-nera
# Processing Record 22 of Set 7 | yamba
# Processing Record 23 of Set 7 | orange walk
# Processing Record 24 of Set 7 | arba minch
# Processing Record 25 of Set 7 | ad darb
# Processing Record 26 of Set 7 | kasongo-lunda
# Processing Record 27 of Set 7 | kirakira
# Processing Record 28 of Set 7 | marquette
# Processing Record 29 of Set 7 | al jawf
# Processing Record 30 of Set 7 | awjilah
# Processing Record 31 of Set 7 | vorkuta
# Processing Record 32 of Set 7 | zyryanskoye
# Processing Record 33 of Set 7 | kholmsk
# Processing Record 34 of Set 7 | saint croix
# Processing Record 35 of Set 7 | alajarvi
# Processing Record 36 of Set 7 | maevatanana
# City not found. Skipping...
# Processing Record 37 of Set 7 | bogale
# Processing Record 38 of Set 7 | hurricane
# Processing Record 39 of Set 7 | marand
# Processing Record 40 of Set 7 | smirnovo
# Processing Record 41 of Set 7 | selfoss
# Processing Record 42 of Set 7 | porbandar
# Processing Record 43 of Set 7 | santa rosa
# Processing Record 44 of Set 7 | sitka
# Processing Record 45 of Set 7 | sarukhan
# Processing Record 46 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 47 of Set 7 | marlin
# Processing Record 48 of Set 7 | alaghsas
# Processing Record 49 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 0 of Set 8 | nema
# Processing Record 1 of Set 8 | amalapuram
# Processing Record 2 of Set 8 | sinop
# Processing Record 3 of Set 8 | lucapa
# Processing Record 4 of Set 8 | nevel'
# Processing Record 5 of Set 8 | slave lake
# Processing Record 6 of Set 8 | rio turbio
# City not found. Skipping...
# Processing Record 7 of Set 8 | zolotonosha
# Processing Record 8 of Set 8 | gilgit
# Processing Record 9 of Set 8 | gornozavodsk
# Processing Record 10 of Set 8 | coffeyville
# Processing Record 11 of Set 8 | nurota
# Processing Record 12 of Set 8 | san luis
# Processing Record 13 of Set 8 | alesund
# Processing Record 14 of Set 8 | goderich
# Processing Record 15 of Set 8 | saipan
# Processing Record 16 of Set 8 | lihue
# Processing Record 17 of Set 8 | pisco
# Processing Record 18 of Set 8 | odda
# Processing Record 19 of Set 8 | fedorovka
# Processing Record 20 of Set 8 | mbuguni
# Processing Record 21 of Set 8 | ijuw
# City not found. Skipping...
# Processing Record 22 of Set 8 | grass valley
# Processing Record 23 of Set 8 | san luis de la loma
# Processing Record 24 of Set 8 | kukuna
# Processing Record 25 of Set 8 | beboto
# Processing Record 26 of Set 8 | mytilene
# Processing Record 27 of Set 8 | kirillov
# Processing Record 28 of Set 8 | riviere du rempart
# Processing Record 29 of Set 8 | essaouira
# Processing Record 30 of Set 8 | ponnani
# Processing Record 31 of Set 8 | la passe
# Processing Record 32 of Set 8 | yung shue wan
# Processing Record 33 of Set 8 | ixtapa
# Processing Record 34 of Set 8 | san patricio
# Processing Record 35 of Set 8 | kununurra
# Processing Record 36 of Set 8 | charters towers
# Processing Record 37 of Set 8 | qui nhon
# Processing Record 38 of Set 8 | ujae
# Processing Record 39 of Set 8 | saint-philippe
# Processing Record 40 of Set 8 | vila velha
# Processing Record 41 of Set 8 | forster
# Processing Record 42 of Set 8 | kirensk
# Processing Record 43 of Set 8 | sooke
# Processing Record 44 of Set 8 | villafranca tirrena
# Processing Record 45 of Set 8 | malkapur
# Processing Record 46 of Set 8 | thatcham
# Processing Record 47 of Set 8 | buncrana
# Processing Record 48 of Set 8 | brokopondo
# Processing Record 49 of Set 8 | beaufort west
# Processing Record 0 of Set 9 | muroto-misakicho
# Processing Record 1 of Set 9 | sao vicente
# Processing Record 2 of Set 9 | hailar
# Processing Record 3 of Set 9 | shush
# Processing Record 4 of Set 9 | ta`u
# Processing Record 5 of Set 9 | dompu
# Processing Record 6 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 9 | fale old settlement
# Processing Record 8 of Set 9 | mount pearl
# Processing Record 9 of Set 9 | krupki
# Processing Record 10 of Set 9 | villa gesell
# Processing Record 11 of Set 9 | beira
# Processing Record 12 of Set 9 | puerto deseado
# Processing Record 13 of Set 9 | paka
# Processing Record 14 of Set 9 | hepo
# Processing Record 15 of Set 9 | wau
# Processing Record 16 of Set 9 | nizhnyaya tura
# Processing Record 17 of Set 9 | tshabong
# Processing Record 18 of Set 9 | barakani
# Processing Record 19 of Set 9 | praia da vitoria
# Processing Record 20 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 9 | huescar
# Processing Record 22 of Set 9 | dakhla
# Processing Record 23 of Set 9 | natal
# Processing Record 24 of Set 9 | amahai
# Processing Record 25 of Set 9 | belmonte
# Processing Record 26 of Set 9 | calama
# Processing Record 27 of Set 9 | north bend
# Processing Record 28 of Set 9 | maintirano
# Processing Record 29 of Set 9 | dingwall
# Processing Record 30 of Set 9 | carahue
# Processing Record 31 of Set 9 | howrah
# Processing Record 32 of Set 9 | amuntai
# Processing Record 33 of Set 9 | moab
# Processing Record 34 of Set 9 | huinca renanco
# Processing Record 35 of Set 9 | nishinoomote
# Processing Record 36 of Set 9 | kitui
# Processing Record 37 of Set 9 | island harbour
# Processing Record 38 of Set 9 | yura
# Processing Record 39 of Set 9 | vizinga
# Processing Record 40 of Set 9 | raduzhny
# Processing Record 41 of Set 9 | tubarjal
# Processing Record 42 of Set 9 | flin flon
# Processing Record 43 of Set 9 | karratha
# Processing Record 44 of Set 9 | talne
# City not found. Skipping...
# Processing Record 45 of Set 9 | magadan
# Processing Record 46 of Set 9 | korotchaevo
# City not found. Skipping...
# Processing Record 47 of Set 9 | gabarin
# Processing Record 48 of Set 9 | goaso
# City not found. Skipping...
# Processing Record 49 of Set 9 | metahara
# Processing Record 0 of Set 10 | luau
# Processing Record 1 of Set 10 | tanjungbalai
# Processing Record 2 of Set 10 | buckhannon
# Processing Record 3 of Set 10 | akureyri
# Processing Record 4 of Set 10 | manaure
# Processing Record 5 of Set 10 | kilindoni
# Processing Record 6 of Set 10 | tangalle
# Processing Record 7 of Set 10 | east london
# Processing Record 8 of Set 10 | crane
# Processing Record 9 of Set 10 | hotan
# Processing Record 10 of Set 10 | brindisi
# Processing Record 11 of Set 10 | safford
# Processing Record 12 of Set 10 | baiyin
# Processing Record 13 of Set 10 | madang
# Processing Record 14 of Set 10 | rossosh'
# Processing Record 15 of Set 10 | kumhari
# Processing Record 16 of Set 10 | rukban
# City not found. Skipping...
# Processing Record 17 of Set 10 | vanino
# Processing Record 18 of Set 10 | abalak
# Processing Record 19 of Set 10 | san antonio
# Processing Record 20 of Set 10 | broome
# Processing Record 21 of Set 10 | jiayuguan
# Processing Record 22 of Set 10 | vilyuchinsk
# Processing Record 23 of Set 10 | banjarmasin
# Processing Record 24 of Set 10 | naze
# Processing Record 25 of Set 10 | kuanda
# Processing Record 26 of Set 10 | kapuskasing
# Processing Record 27 of Set 10 | uturoa
# Processing Record 28 of Set 10 | north vernon
# Processing Record 29 of Set 10 | gizo
# Processing Record 30 of Set 10 | zelenogradsk
# Processing Record 31 of Set 10 | choibalsan
# Processing Record 32 of Set 10 | angaur state
# Processing Record 33 of Set 10 | bokani
# Processing Record 34 of Set 10 | taltal
# Processing Record 35 of Set 10 | progreso
# Processing Record 36 of Set 10 | arlington
# Processing Record 37 of Set 10 | aracataca
# Processing Record 38 of Set 10 | majene
# Processing Record 39 of Set 10 | huntington park
# Processing Record 40 of Set 10 | sandnessjoen
# Processing Record 41 of Set 10 | kodinsk
# Processing Record 42 of Set 10 | kavieng
# Processing Record 43 of Set 10 | chikmagalur
# Processing Record 44 of Set 10 | el granada
# Processing Record 45 of Set 10 | mulanje
# Processing Record 46 of Set 10 | soe
# Processing Record 47 of Set 10 | palikir - national government center
# Processing Record 48 of Set 10 | anaco
# Processing Record 49 of Set 10 | lashio
# Processing Record 0 of Set 11 | comandante fontana
# Processing Record 1 of Set 11 | zhanaozen
# Processing Record 2 of Set 11 | medicine hat
# Processing Record 3 of Set 11 | churachandpur
# Processing Record 4 of Set 11 | rocha
# Processing Record 5 of Set 11 | zherdevka
# Processing Record 6 of Set 11 | balkashino
# Processing Record 7 of Set 11 | tianpeng
# Processing Record 8 of Set 11 | sao jose da coroa grande
# Processing Record 9 of Set 11 | bogo
# Processing Record 10 of Set 11 | pitimbu
# Processing Record 11 of Set 11 | potosi
# Processing Record 12 of Set 11 | byron
# Processing Record 13 of Set 11 | revda
# Processing Record 14 of Set 11 | port hedland
# Processing Record 15 of Set 11 | qamdo
# Processing Record 16 of Set 11 | conception bay south
# Processing Record 17 of Set 11 | motygino
# Processing Record 18 of Set 11 | saint-lin-laurentides
# Processing Record 19 of Set 11 | howard springs
# Processing Record 20 of Set 11 | magistral'nyy
# Processing Record 21 of Set 11 | boulsa
# Processing Record 22 of Set 11 | aswan
# Processing Record 23 of Set 11 | yaren
# Processing Record 24 of Set 11 | port-vila
# Processing Record 25 of Set 11 | geidam
# Processing Record 26 of Set 11 | caxito
# Processing Record 27 of Set 11 | northam
# Processing Record 28 of Set 11 | nova sintra
# Processing Record 29 of Set 11 | bassila
# Processing Record 30 of Set 11 | curillo
# Processing Record 31 of Set 11 | nicoya
# Processing Record 32 of Set 11 | ad dilam
# Processing Record 33 of Set 11 | savsat
# Processing Record 34 of Set 11 | tsevie
# Processing Record 35 of Set 11 | tenno
# Processing Record 36 of Set 11 | yellandu
# Processing Record 37 of Set 11 | quartu sant'elena
# Processing Record 38 of Set 11 | seoni malwa
# Processing Record 39 of Set 11 | zeerust
# Processing Record 40 of Set 11 | patong
# Processing Record 41 of Set 11 | marsabit
# Processing Record 42 of Set 11 | urangan
# Processing Record 43 of Set 11 | labytnangi
# Processing Record 44 of Set 11 | kerikeri
# Processing Record 45 of Set 11 | bandarbeyla
# Processing Record 46 of Set 11 | murun-kuren
# Processing Record 47 of Set 11 | kokopo
# Processing Record 48 of Set 11 | turkmenbasy
# Processing Record 49 of Set 11 | sturgeon bay
# Processing Record 0 of Set 12 | lata
# Processing Record 1 of Set 12 | uzgen
# Processing Record 2 of Set 12 | vilhena
# Processing Record 3 of Set 12 | amga
# Processing Record 4 of Set 12 | jayapura
# Processing Record 5 of Set 12 | khvansar
# Processing Record 6 of Set 12 | tuskegee
# Processing Record 7 of Set 12 | westport
# Processing Record 8 of Set 12 | piacabucu
# Processing Record 9 of Set 12 | jiagedaqi
# Processing Record 10 of Set 12 | sao joao da barra
# Processing Record 11 of Set 12 | fort st. john
# Processing Record 12 of Set 12 | chegdomyn
# Processing Record 13 of Set 12 | fort-shevchenko
# Processing Record 14 of Set 12 | prince albert
# Processing Record 15 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 16 of Set 12 | kurlovo
# Processing Record 17 of Set 12 | port macquarie
# Processing Record 18 of Set 12 | engenheiro beltrao
# Processing Record 19 of Set 12 | brisas barra de suchiate
# Processing Record 20 of Set 12 | antofagasta
# Processing Record 21 of Set 12 | novogornyy
# Processing Record 22 of Set 12 | sabang
# Processing Record 23 of Set 12 | ust'-barguzin
# Processing Record 24 of Set 12 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 12 | zaragoza
# Processing Record 26 of Set 12 | coyutla
# Processing Record 27 of Set 12 | campbellton
# Processing Record 28 of Set 12 | olinda
# Processing Record 29 of Set 12 | jalqani
# Processing Record 30 of Set 12 | bamboo flat
# Processing Record 31 of Set 12 | horta
# Processing Record 32 of Set 12 | antigonish
# Processing Record 33 of Set 12 | kaa-khem
# Processing Record 34 of Set 12 | caluula
# Processing Record 35 of Set 12 | guantanamo
# Processing Record 36 of Set 12 | safaga
# Processing Record 37 of Set 12 | moyynkum
# Processing Record 38 of Set 12 | catabola
# Processing Record 39 of Set 12 | alindao
# Processing Record 40 of Set 12 | gaoping
# Processing Record 41 of Set 12 | boende
# Processing Record 42 of Set 12 | flying fish cove
# Processing Record 43 of Set 12 | lonar
# Processing Record 44 of Set 12 | norman gardens
# Processing Record 45 of Set 12 | castillos
# Processing Record 46 of Set 12 | iwanai
# Processing Record 47 of Set 12 | tingo maria
# Processing Record 48 of Set 12 | kem'
# Processing Record 49 of Set 12 | valdivia
# Processing Record 0 of Set 13 | saint-joseph
# Processing Record 1 of Set 13 | kavaratti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    thompson  55.7435  -97.8558     -3.91        46           0        4.12
# 1      kamthi  21.2333   79.2000     32.19        45          61        3.51
# 2   adamstown -25.0660 -130.1015     23.55        85         100        7.81
# 3  constantia  44.1833   28.6500     11.50        73          73        2.29
# 4   papatowai -46.5619  169.4708      9.12        93          15        3.43
#
#   Country        Date
# 0      CA  1714240073
# 1      IN  1714240074
# 2      PN  1714240074
# 3      RO  1714240074
# 4      NZ  1714240074

# %%
# Export the City_Data into a csv
from pathlib import Path  
filepath = Path('python-api-challenge/output_data/cities.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)       
city_data_df.to_csv("python-api-challenge/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("python-api-challenge/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          thompson  55.7435  -97.8558     -3.91        46           0
# 1            kamthi  21.2333   79.2000     32.19        45          61
# 2         adamstown -25.0660 -130.1015     23.55        85         100
# 3        constantia  44.1833   28.6500     11.50        73          73
# 4         papatowai -46.5619  169.4708      9.12        93          15
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      CA  1714240073
# 1              3.51      IN  1714240074
# 2              7.81      PN  1714240074
# 3              2.29      RO  1714240074
# 4              3.43      NZ  1714240074

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
temp = city_data_df['Max Temp']

x = latitude
y = temp
plt.scatter(x, y, edgecolors='black')
plt.title('City Max Latitude vs. Temperature (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
humidity = city_data_df['Humidity']
x = latitude
y = humidity
plt.scatter(x,y,edgecolors='black')
plt.title('City Max Latitude vs. Humidity (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']
x = latitude
y = cloudiness
plt.scatter(x,y,edgecolors='black')
plt.title('City Max Latitude vs. Humidity (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
wind_speed = city_data_df['Wind Speed']
x = latitude
y = wind_speed
plt.scatter(x,y,edgecolors='black')
plt.title('City Max Latitude vs. Humidity (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values, marker="o", color="skyblue", edgecolors="black")
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(min(x_values),min(y_values)),fontsize=20,color="red")
    plt.xlabel('Latitude')
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 thompson  55.7435  -97.8558     -3.91        46           0
# 1                   kamthi  21.2333   79.2000     32.19        45          61
# 3               constantia  44.1833   28.6500     11.50        73          73
# 5                    vadso  70.0744   29.7487      1.09        80         100
# 8        bikenibeu village   1.3673  173.1241     26.98        89          75
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      CA  1714240073
# 1              3.51      IN  1714240074
# 3              2.29      RO  1714240074
# 5              5.66      NO  1714240074
# 8              3.60      KI  1714240074

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] <=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                          adamstown -25.0660 -130.1015     23.55        85
# 4                          papatowai -46.5619  169.4708      9.12        93
# 6                              palpa -14.5336  -75.1856     30.92        37
# 7                          grytviken -54.2811  -36.5092      3.83        99
# 11       edinburgh of the seven seas -37.0676  -12.3116     12.83        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2               100        7.81      PN  1714240074
# 4                15        3.43      NZ  1714240074
# 6                34        4.21      PE  1714240074
# 7               100        5.04      GS  1714240074
# 11               87       12.55      SH  1714240074

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Max Temperature (2024-04-26)")
plt.ylabel("Max Temperature")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.7582483548948161

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Max Temperature (2024-04-26)")
plt.ylabel("Max Temperature")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.5917067455444679

# %% [markdown]
# **Discussion about the linear relationship:** Temperatures are higher in cities located closer to the equator (0) and temperatures are lower in cities located further away from the equator. This trend is observed in both the norther and southern hemispheres.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Humidity (2024-04-26)")
plt.ylabel("Humidity")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.06115897939396126

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Humidity (2024-04-26)")
plt.ylabel("Humidity")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.01778826289162497

# %% [markdown]
# **Discussion about the linear relationship:** Humidity rises the further a city is located from the equator (0) in the northern hemisphere. Humidity lowers the further a city is located from the equator in the souther hemisphere. There is no observable correlation in this trend.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Cloudiness (2024-04-26)")
plt.ylabel("Cloudiness")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.02639467802810163

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Cloudiness (2024-04-26)")
plt.ylabel("Cloudiness")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.01680637469664127

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness is roughly equal in both the northern and southern hemispheres. A greater number of cities in the northern hemisphere fall along the slope of the line, which causes the perception that the northern hemisphere is cloudier than the southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

linear_regression(x_values, y_values)
plt.title(f"Northern Hemi. Latitudes vs. Windiness (2024-04-26)")
plt.ylabel("Wind Speed")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.00041422642654088124

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

linear_regression(x_values, y_values)
plt.title(f"Southern Hemi. Latitudes vs. Windiness (2024-04-26)")
plt.ylabel("Wind Speed")
plt.grid()
plt.show()
# Out:
# The r-squared is: 0.0730477180166829

# %% [markdown]
# **Discussion about the linear relationship:** Windiness is quite consistent in the northern hemisphere. Windiness picked up sharply in cities further away from the equator (0) in the southern hemisphere.
