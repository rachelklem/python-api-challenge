# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}appid={weather_api_key}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | perth
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | sodra sandby
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | lihue
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 1 | bamboo flat
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | puerto natales
# Processing Record 12 of Set 1 | tura
# Processing Record 13 of Set 1 | mejit
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | klyuchi
# Processing Record 17 of Set 1 | invercargill
# Processing Record 18 of Set 1 | mudanjiang
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | manavalakurichi
# Processing Record 21 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | wailua homesteads
# Processing Record 25 of Set 1 | vernon
# Processing Record 26 of Set 1 | isafjordur
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | salinopolis
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | trinity beach
# Processing Record 31 of Set 1 | atafu village
# Processing Record 32 of Set 1 | krasnoslobodsk
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | pangody
# Processing Record 35 of Set 1 | ashmun
# Processing Record 36 of Set 1 | pudasjarvi
# Processing Record 37 of Set 1 | lorengau
# Processing Record 38 of Set 1 | geraldton
# Processing Record 39 of Set 1 | moron
# Processing Record 40 of Set 1 | vadso
# Processing Record 41 of Set 1 | fang
# Processing Record 42 of Set 1 | nemuro
# Processing Record 43 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 44 of Set 1 | west island
# Processing Record 45 of Set 1 | constantia
# Processing Record 46 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 47 of Set 1 | corowa
# Processing Record 48 of Set 1 | dudinka
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | blackmans bay
# Processing Record 0 of Set 2 | hereford
# Processing Record 1 of Set 2 | yangor
# City not found. Skipping...
# Processing Record 2 of Set 2 | uvira
# Processing Record 3 of Set 2 | chernyshevskiy
# Processing Record 4 of Set 2 | acapulco de juarez
# Processing Record 5 of Set 2 | dawson creek
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | tobruk
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | james island
# City not found. Skipping...
# Processing Record 10 of Set 2 | uturoa
# Processing Record 11 of Set 2 | qaqortoq
# Processing Record 12 of Set 2 | taltal
# Processing Record 13 of Set 2 | arteche
# Processing Record 14 of Set 2 | northam
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | hundested
# Processing Record 18 of Set 2 | mytilene
# Processing Record 19 of Set 2 | saipan
# Processing Record 20 of Set 2 | mainaguri
# Processing Record 21 of Set 2 | tual
# Processing Record 22 of Set 2 | nova sintra
# Processing Record 23 of Set 2 | margaret river
# Processing Record 24 of Set 2 | marsaskala
# City not found. Skipping...
# Processing Record 25 of Set 2 | udachny
# Processing Record 26 of Set 2 | st. john's
# Processing Record 27 of Set 2 | harper
# Processing Record 28 of Set 2 | gadzhiyevo
# Processing Record 29 of Set 2 | ishigaki
# Processing Record 30 of Set 2 | maceio
# Processing Record 31 of Set 2 | ulan bator
# Processing Record 32 of Set 2 | sitka
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | buncrana
# Processing Record 35 of Set 2 | flying fish cove
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | aasiaat
# Processing Record 39 of Set 2 | papatowai
# Processing Record 40 of Set 2 | souillac
# Processing Record 41 of Set 2 | antofagasta
# Processing Record 42 of Set 2 | stanley
# Processing Record 43 of Set 2 | mitu
# Processing Record 44 of Set 2 | san antonio de pale
# Processing Record 45 of Set 2 | okhotsk
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | stephenville
# Processing Record 0 of Set 3 | bredasdorp
# Processing Record 1 of Set 3 | kurmuk
# Processing Record 2 of Set 3 | nichinan
# Processing Record 3 of Set 3 | afaahiti
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | kupang
# Processing Record 6 of Set 3 | bathsheba
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | nguigmi
# Processing Record 9 of Set 3 | puerto deseado
# Processing Record 10 of Set 3 | domat
# Processing Record 11 of Set 3 | palapye
# Processing Record 12 of Set 3 | brisas de zicatela
# Processing Record 13 of Set 3 | olonkinbyen
# Processing Record 14 of Set 3 | huarmey
# Processing Record 15 of Set 3 | port mathurin
# Processing Record 16 of Set 3 | praia
# Processing Record 17 of Set 3 | tionk essil
# Processing Record 18 of Set 3 | ulsteinvik
# Processing Record 19 of Set 3 | mount gambier
# Processing Record 20 of Set 3 | utrik
# Processing Record 21 of Set 3 | tuapse
# Processing Record 22 of Set 3 | tralee
# Processing Record 23 of Set 3 | jerez de garcia salinas
# Processing Record 24 of Set 3 | aykhal
# Processing Record 25 of Set 3 | jianguang
# Processing Record 26 of Set 3 | kaarela
# City not found. Skipping...
# Processing Record 27 of Set 3 | jayapura
# Processing Record 28 of Set 3 | villa gesell
# Processing Record 29 of Set 3 | floro
# Processing Record 30 of Set 3 | rajanpur
# Processing Record 31 of Set 3 | ust-nera
# Processing Record 32 of Set 3 | flores da cunha
# Processing Record 33 of Set 3 | bernal
# Processing Record 34 of Set 3 | gangapur
# Processing Record 35 of Set 3 | san rafael
# Processing Record 36 of Set 3 | kavaratti
# Processing Record 37 of Set 3 | whitehorse
# Processing Record 38 of Set 3 | burlington
# Processing Record 39 of Set 3 | kununurra
# Processing Record 40 of Set 3 | hotan
# Processing Record 41 of Set 3 | bontang
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | al hilaliyya
# Processing Record 44 of Set 3 | choma
# Processing Record 45 of Set 3 | saskatoon
# Processing Record 46 of Set 3 | kosong
# Processing Record 47 of Set 3 | north bend
# Processing Record 48 of Set 3 | puerto cabezas
# Processing Record 49 of Set 3 | codrington
# Processing Record 0 of Set 4 | xai-xai
# Processing Record 1 of Set 4 | cannonvale
# Processing Record 2 of Set 4 | bermejo
# Processing Record 3 of Set 4 | sipote
# Processing Record 4 of Set 4 | george town
# Processing Record 5 of Set 4 | turbat
# Processing Record 6 of Set 4 | vilyuchinsk
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | nenjiang
# Processing Record 9 of Set 4 | kabalo
# Processing Record 10 of Set 4 | uliastay
# Processing Record 11 of Set 4 | saint-francois
# Processing Record 12 of Set 4 | tsiombe
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | portsmouth
# Processing Record 15 of Set 4 | hermanus
# Processing Record 16 of Set 4 | grand-bassam
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | najaf
# Processing Record 19 of Set 4 | antonio enes
# Processing Record 20 of Set 4 | masterton
# Processing Record 21 of Set 4 | conception bay south
# Processing Record 22 of Set 4 | sao felix do xingu
# Processing Record 23 of Set 4 | college
# Processing Record 24 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 25 of Set 4 | powell river
# Processing Record 26 of Set 4 | macapa
# Processing Record 27 of Set 4 | pandan
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | borogontsy
# Processing Record 30 of Set 4 | piton saint-leu
# Processing Record 31 of Set 4 | kikwit
# Processing Record 32 of Set 4 | manggar
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | kavarna
# Processing Record 35 of Set 4 | hawaiian paradise park
# Processing Record 36 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 4 | haiku-pauwela
# Processing Record 38 of Set 4 | auki
# Processing Record 39 of Set 4 | severobaykal'sk
# Processing Record 40 of Set 4 | tazovsky
# Processing Record 41 of Set 4 | shimoda
# Processing Record 42 of Set 4 | opuwo
# Processing Record 43 of Set 4 | muynoq
# Processing Record 44 of Set 4 | puerto colombia
# Processing Record 45 of Set 4 | cabo san lucas
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | ilulissat
# Processing Record 48 of Set 4 | newman
# Processing Record 49 of Set 4 | ende
# Processing Record 0 of Set 5 | thompson
# Processing Record 1 of Set 5 | paramonga
# Processing Record 2 of Set 5 | palu
# Processing Record 3 of Set 5 | teknaf
# Processing Record 4 of Set 5 | trincomalee
# Processing Record 5 of Set 5 | lahaina
# Processing Record 6 of Set 5 | sirsaganj
# Processing Record 7 of Set 5 | sogndal
# Processing Record 8 of Set 5 | empalme
# Processing Record 9 of Set 5 | tamanrasset
# Processing Record 10 of Set 5 | santa isabel
# Processing Record 11 of Set 5 | usinsk
# Processing Record 12 of Set 5 | alvand
# Processing Record 13 of Set 5 | zaozersk
# Processing Record 14 of Set 5 | kourou
# Processing Record 15 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 16 of Set 5 | holualoa
# Processing Record 17 of Set 5 | bilibino
# Processing Record 18 of Set 5 | west bay
# Processing Record 19 of Set 5 | kingston
# Processing Record 20 of Set 5 | leticia
# Processing Record 21 of Set 5 | liupanshui
# City not found. Skipping...
# Processing Record 22 of Set 5 | alice springs
# Processing Record 23 of Set 5 | walvis bay
# Processing Record 24 of Set 5 | ciudad lazaro cardenas
# Processing Record 25 of Set 5 | papao
# Processing Record 26 of Set 5 | warrnambool
# Processing Record 27 of Set 5 | hilo
# Processing Record 28 of Set 5 | solsona
# Processing Record 29 of Set 5 | traipu
# Processing Record 30 of Set 5 | galliano
# Processing Record 31 of Set 5 | morehead city
# Processing Record 32 of Set 5 | kotido
# Processing Record 33 of Set 5 | island harbour
# Processing Record 34 of Set 5 | saudarkrokur
# Processing Record 35 of Set 5 | richards bay
# Processing Record 36 of Set 5 | realico
# Processing Record 37 of Set 5 | sinop
# Processing Record 38 of Set 5 | colonia
# Processing Record 39 of Set 5 | cholpon-ata
# Processing Record 40 of Set 5 | poxoreo
# Processing Record 41 of Set 5 | shanhaiguan
# Processing Record 42 of Set 5 | revelstoke
# Processing Record 43 of Set 5 | sodankyla
# Processing Record 44 of Set 5 | tierra nueva
# Processing Record 45 of Set 5 | tahe
# Processing Record 46 of Set 5 | timiryazevskoye
# Processing Record 47 of Set 5 | yelizovo
# Processing Record 48 of Set 5 | sant'antioco
# Processing Record 49 of Set 5 | dumai
# Processing Record 0 of Set 6 | al kharj
# Processing Record 1 of Set 6 | buloh kasap
# Processing Record 2 of Set 6 | gorontalo
# Processing Record 3 of Set 6 | maputo
# Processing Record 4 of Set 6 | shubarshi
# Processing Record 5 of Set 6 | oyama
# Processing Record 6 of Set 6 | maumere
# Processing Record 7 of Set 6 | vredenburg
# City not found. Skipping...
# Processing Record 8 of Set 6 | iskateley
# Processing Record 9 of Set 6 | yanam
# Processing Record 10 of Set 6 | saint-paul
# Processing Record 11 of Set 6 | kemijarvi
# Processing Record 12 of Set 6 | cabinda
# Processing Record 13 of Set 6 | chongwe
# Processing Record 14 of Set 6 | smara
# Processing Record 15 of Set 6 | la sarre
# Processing Record 16 of Set 6 | qusmuryn
# Processing Record 17 of Set 6 | westport
# Processing Record 18 of Set 6 | tataouine
# Processing Record 19 of Set 6 | axim
# Processing Record 20 of Set 6 | hithadhoo
# Processing Record 21 of Set 6 | homer
# Processing Record 22 of Set 6 | nicoya
# Processing Record 23 of Set 6 | fada n'gourma
# Processing Record 24 of Set 6 | sisimiut
# Processing Record 25 of Set 6 | anadyr
# Processing Record 26 of Set 6 | labrador city
# Processing Record 27 of Set 6 | ensenada
# Processing Record 28 of Set 6 | hasaki
# Processing Record 29 of Set 6 | ratnagiri
# Processing Record 30 of Set 6 | manatutu
# City not found. Skipping...
# Processing Record 31 of Set 6 | saurimo
# Processing Record 32 of Set 6 | bejubang dua
# City not found. Skipping...
# Processing Record 33 of Set 6 | upington
# Processing Record 34 of Set 6 | yasuj
# Processing Record 35 of Set 6 | la romana
# Processing Record 36 of Set 6 | cadale
# Processing Record 37 of Set 6 | egilsstadir
# Processing Record 38 of Set 6 | mwingi
# Processing Record 39 of Set 6 | sormiou
# City not found. Skipping...
# Processing Record 40 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 6 | jumla
# Processing Record 42 of Set 6 | balboa
# Processing Record 43 of Set 6 | tadine
# Processing Record 44 of Set 6 | san angelo
# Processing Record 45 of Set 6 | yichang
# Processing Record 46 of Set 6 | ola
# Processing Record 47 of Set 6 | osakarovka
# Processing Record 48 of Set 6 | palora
# Processing Record 49 of Set 6 | ariquemes
# Processing Record 0 of Set 7 | tupa
# Processing Record 1 of Set 7 | matiguas
# Processing Record 2 of Set 7 | tanki leendert
# City not found. Skipping...
# Processing Record 3 of Set 7 | sulphur
# Processing Record 4 of Set 7 | villa dolores
# Processing Record 5 of Set 7 | sinabang
# Processing Record 6 of Set 7 | panacan
# Processing Record 7 of Set 7 | natal
# Processing Record 8 of Set 7 | acarau
# Processing Record 9 of Set 7 | puerto berrio
# Processing Record 10 of Set 7 | keflavik
# Processing Record 11 of Set 7 | mwinilunga
# Processing Record 12 of Set 7 | port lincoln
# Processing Record 13 of Set 7 | howard springs
# Processing Record 14 of Set 7 | queenstown
# Processing Record 15 of Set 7 | las lomitas
# Processing Record 16 of Set 7 | i-n-salah
# Processing Record 17 of Set 7 | quellon
# Processing Record 18 of Set 7 | la'ie
# Processing Record 19 of Set 7 | xinyuan
# Processing Record 20 of Set 7 | borkum
# Processing Record 21 of Set 7 | puerto el triunfo
# Processing Record 22 of Set 7 | lerwick
# Processing Record 23 of Set 7 | antsiranana
# Processing Record 24 of Set 7 | ostashkov
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | balqash
# Processing Record 27 of Set 7 | vorgashor
# Processing Record 28 of Set 7 | ilhabela
# Processing Record 29 of Set 7 | urucara
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | al ghayzah
# Processing Record 32 of Set 7 | ponta delgada
# Processing Record 33 of Set 7 | remire-montjoly
# Processing Record 34 of Set 7 | turpan
# Processing Record 35 of Set 7 | east end
# Processing Record 36 of Set 7 | al qadarif
# Processing Record 37 of Set 7 | coquimbo
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | kapoeta
# Processing Record 40 of Set 7 | polyarnyy
# Processing Record 41 of Set 7 | muana
# Processing Record 42 of Set 7 | enewetak
# Processing Record 43 of Set 7 | petauke
# Processing Record 44 of Set 7 | primero de mayo
# Processing Record 45 of Set 7 | barguzin
# Processing Record 46 of Set 7 | kudahuvadhoo
# Processing Record 47 of Set 7 | sao vicente
# Processing Record 48 of Set 7 | jurbarkas
# Processing Record 49 of Set 7 | ardabil
# Processing Record 0 of Set 8 | ales
# Processing Record 1 of Set 8 | damboa
# Processing Record 2 of Set 8 | new norfolk
# Processing Record 3 of Set 8 | thinadhoo
# Processing Record 4 of Set 8 | ambad
# Processing Record 5 of Set 8 | fiambala
# Processing Record 6 of Set 8 | inyati
# Processing Record 7 of Set 8 | argostolion
# Processing Record 8 of Set 8 | yagry
# City not found. Skipping...
# Processing Record 9 of Set 8 | libreville
# Processing Record 10 of Set 8 | kapa'a
# Processing Record 11 of Set 8 | gillette
# Processing Record 12 of Set 8 | talavera la real
# Processing Record 13 of Set 8 | nieuw amsterdam
# Processing Record 14 of Set 8 | kalifornsky
# Processing Record 15 of Set 8 | pemangkat
# Processing Record 16 of Set 8 | tlahualilo de zaragoza
# Processing Record 17 of Set 8 | arno
# Processing Record 18 of Set 8 | chibougamau
# Processing Record 19 of Set 8 | minas de marcona
# Processing Record 20 of Set 8 | yerofey pavlovich
# Processing Record 21 of Set 8 | abqaiq
# Processing Record 22 of Set 8 | sao gabriel da cachoeira
# Processing Record 23 of Set 8 | chiredzi
# Processing Record 24 of Set 8 | terrace
# Processing Record 25 of Set 8 | nchelenge
# Processing Record 26 of Set 8 | paita
# Processing Record 27 of Set 8 | priozersk
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | chibuto
# Processing Record 30 of Set 8 | sao joao da barra
# Processing Record 31 of Set 8 | machico
# Processing Record 32 of Set 8 | ghat
# Processing Record 33 of Set 8 | luderitz
# Processing Record 34 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 35 of Set 8 | fale old settlement
# Processing Record 36 of Set 8 | ust-tsilma
# Processing Record 37 of Set 8 | kano
# Processing Record 38 of Set 8 | manaus
# Processing Record 39 of Set 8 | andovoranto
# Processing Record 40 of Set 8 | niafunke
# Processing Record 41 of Set 8 | mpika
# Processing Record 42 of Set 8 | shanwei
# Processing Record 43 of Set 8 | zambezi
# Processing Record 44 of Set 8 | hamilton
# Processing Record 45 of Set 8 | undurkhaan
# Processing Record 46 of Set 8 | miyanoura
# City not found. Skipping...
# Processing Record 47 of Set 8 | coromandel
# Processing Record 48 of Set 8 | la paz
# Processing Record 49 of Set 8 | sebis
# Processing Record 0 of Set 9 | castillos
# Processing Record 1 of Set 9 | san isidro
# Processing Record 2 of Set 9 | ta`u
# Processing Record 3 of Set 9 | bikenibeu village
# Processing Record 4 of Set 9 | rawson
# Processing Record 5 of Set 9 | puerto armuelles
# Processing Record 6 of Set 9 | masumbwe
# Processing Record 7 of Set 9 | nyurba
# Processing Record 8 of Set 9 | chipurupalle
# Processing Record 9 of Set 9 | brookings
# Processing Record 10 of Set 9 | hassi messaoud
# Processing Record 11 of Set 9 | kapuskasing
# Processing Record 12 of Set 9 | sonoita
# Processing Record 13 of Set 9 | chanika
# Processing Record 14 of Set 9 | sungailiat
# Processing Record 15 of Set 9 | estevan
# Processing Record 16 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 17 of Set 9 | mulki
# Processing Record 18 of Set 9 | tangalle
# Processing Record 19 of Set 9 | greenville
# Processing Record 20 of Set 9 | fortuna
# Processing Record 21 of Set 9 | vilyuysk
# Processing Record 22 of Set 9 | svay rieng
# Processing Record 23 of Set 9 | humaita
# Processing Record 24 of Set 9 | nuuk
# Processing Record 25 of Set 9 | arraial do cabo
# Processing Record 26 of Set 9 | kayangel
# Processing Record 27 of Set 9 | al quwayrah
# Processing Record 28 of Set 9 | pacific grove
# Processing Record 29 of Set 9 | zyryanovsk
# Processing Record 30 of Set 9 | tofol
# Processing Record 31 of Set 9 | broome
# Processing Record 32 of Set 9 | bairnsdale
# Processing Record 33 of Set 9 | yasothon
# Processing Record 34 of Set 9 | grande prairie
# Processing Record 35 of Set 9 | yelovo
# Processing Record 36 of Set 9 | goz beida
# Processing Record 37 of Set 9 | nagqu
# Processing Record 38 of Set 9 | oriximina
# Processing Record 39 of Set 9 | messini
# Processing Record 40 of Set 9 | san jose del guaviare
# Processing Record 41 of Set 9 | thenzawl
# Processing Record 42 of Set 9 | alesund
# Processing Record 43 of Set 9 | yarmouth
# Processing Record 44 of Set 9 | pagar alam
# Processing Record 45 of Set 9 | bardai
# Processing Record 46 of Set 9 | sulejow
# Processing Record 47 of Set 9 | palikir - national government center
# Processing Record 48 of Set 9 | tolanaro
# Processing Record 49 of Set 9 | magadan
# Processing Record 0 of Set 10 | shirgaon
# Processing Record 1 of Set 10 | santa maria
# Processing Record 2 of Set 10 | port macquarie
# Processing Record 3 of Set 10 | horodok
# Processing Record 4 of Set 10 | atasu
# Processing Record 5 of Set 10 | happy valley-goose bay
# Processing Record 6 of Set 10 | surgut
# Processing Record 7 of Set 10 | morant bay
# Processing Record 8 of Set 10 | sang-e charak
# Processing Record 9 of Set 10 | colle di val d'elsa
# Processing Record 10 of Set 10 | el calafate
# Processing Record 11 of Set 10 | ornskoldsvik
# Processing Record 12 of Set 10 | anabar
# City not found. Skipping...
# Processing Record 13 of Set 10 | ban phe
# City not found. Skipping...
# Processing Record 14 of Set 10 | arroyo
# Processing Record 15 of Set 10 | alnashi
# Processing Record 16 of Set 10 | kutum
# Processing Record 17 of Set 10 | al jawf
# Processing Record 18 of Set 10 | swift current
# Processing Record 19 of Set 10 | dzhambeyty
# Processing Record 20 of Set 10 | crane
# Processing Record 21 of Set 10 | vrontados
# Processing Record 22 of Set 10 | salalah
# Processing Record 23 of Set 10 | arar
# Processing Record 24 of Set 10 | ferkessedougou
# Processing Record 25 of Set 10 | minacu
# City not found. Skipping...
# Processing Record 26 of Set 10 | xinzo de limia
# Processing Record 27 of Set 10 | vanino
# Processing Record 28 of Set 10 | chichen-itza
# Processing Record 29 of Set 10 | quatre cocos
# Processing Record 30 of Set 10 | tidjikja
# Processing Record 31 of Set 10 | taoudenni
# Processing Record 32 of Set 10 | zonguldak
# Processing Record 33 of Set 10 | cuatro cienegas de carranza
# Processing Record 34 of Set 10 | kataysk
# Processing Record 35 of Set 10 | palmares do sul
# Processing Record 36 of Set 10 | inhambane
# Processing Record 37 of Set 10 | vila franca do campo
# Processing Record 38 of Set 10 | itogon
# Processing Record 39 of Set 10 | pa daet
# Processing Record 40 of Set 10 | meizhou
# Processing Record 41 of Set 10 | murzuq
# Processing Record 42 of Set 10 | korsakov
# Processing Record 43 of Set 10 | mont-dore
# Processing Record 44 of Set 10 | walla walla
# Processing Record 45 of Set 10 | marianna
# Processing Record 46 of Set 10 | tobi village
# City not found. Skipping...
# Processing Record 47 of Set 10 | gizo
# Processing Record 48 of Set 10 | novaya igirma
# Processing Record 49 of Set 10 | bukoba
# Processing Record 0 of Set 11 | talcahuano
# Processing Record 1 of Set 11 | banjarmasin
# Processing Record 2 of Set 11 | mayya
# Processing Record 3 of Set 11 | shingu
# Processing Record 4 of Set 11 | ancud
# Processing Record 5 of Set 11 | jokioinen
# Processing Record 6 of Set 11 | horta
# Processing Record 7 of Set 11 | ketchikan
# Processing Record 8 of Set 11 | badger
# Processing Record 9 of Set 11 | xilin hot
# Processing Record 10 of Set 11 | general villegas
# Processing Record 11 of Set 11 | caconda
# Processing Record 12 of Set 11 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 13 of Set 11 | baikonur
# Processing Record 14 of Set 11 | port douglas
# Processing Record 15 of Set 11 | labytnangi
# Processing Record 16 of Set 11 | orkeny
# Processing Record 17 of Set 11 | kijang
# Processing Record 18 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 11 | heroica caborca
# Processing Record 20 of Set 11 | rongelap
# Processing Record 21 of Set 11 | el granada
# Processing Record 22 of Set 11 | luganville
# Processing Record 23 of Set 11 | moussoro
# Processing Record 24 of Set 11 | carriere
# Processing Record 25 of Set 11 | magdagachi
# Processing Record 26 of Set 11 | rexburg
# Processing Record 27 of Set 11 | laojunmiao
# Processing Record 28 of Set 11 | les cayes
# Processing Record 29 of Set 11 | senta
# Processing Record 30 of Set 11 | dire
# Processing Record 31 of Set 11 | san julian
# Processing Record 32 of Set 11 | belyy yar
# Processing Record 33 of Set 11 | punta del este
# Processing Record 34 of Set 11 | loutraki
# Processing Record 35 of Set 11 | itoman
# Processing Record 36 of Set 11 | naze
# Processing Record 37 of Set 11 | la passe
# Processing Record 38 of Set 11 | sheregesh
# Processing Record 39 of Set 11 | villa carlos paz
# Processing Record 40 of Set 11 | luxor
# Processing Record 41 of Set 11 | strezhevoy
# Processing Record 42 of Set 11 | malmesbury
# Processing Record 43 of Set 11 | greymouth
# Processing Record 44 of Set 11 | 'ibri
# City not found. Skipping...
# Processing Record 45 of Set 11 | bridgewater
# Processing Record 46 of Set 11 | kamaishi
# Processing Record 47 of Set 11 | ghatampur
# Processing Record 48 of Set 11 | junction city
# Processing Record 49 of Set 11 | arkhangel'sk
# Processing Record 0 of Set 12 | sandnessjoen
# Processing Record 1 of Set 12 | margate
# Processing Record 2 of Set 12 | orapa
# Processing Record 3 of Set 12 | chonchi
# Processing Record 4 of Set 12 | zhongshu
# Processing Record 5 of Set 12 | lazaro cardenas
# Processing Record 6 of Set 12 | salto de agua
# Processing Record 7 of Set 12 | badlapur
# Processing Record 8 of Set 12 | brokopondo
# Processing Record 9 of Set 12 | ebon
# Processing Record 10 of Set 12 | mocimboa
# Processing Record 11 of Set 12 | lucapa
# Processing Record 12 of Set 12 | mil'kovo
# Processing Record 13 of Set 12 | tours
# Processing Record 14 of Set 12 | bubaque
# Processing Record 15 of Set 12 | amalapuram
# Processing Record 16 of Set 12 | kauhava
# Processing Record 17 of Set 12 | ikwiriri
# Processing Record 18 of Set 12 | baijiantan
# Processing Record 19 of Set 12 | manta
# Processing Record 20 of Set 12 | porto novo
# Processing Record 21 of Set 12 | lionel town
# Processing Record 22 of Set 12 | fengkou
# Processing Record 23 of Set 12 | puro
# Processing Record 24 of Set 12 | pont rouge
# Processing Record 25 of Set 12 | taroudant
# Processing Record 26 of Set 12 | wewak
# Processing Record 27 of Set 12 | labin
# Processing Record 28 of Set 12 | pueblo nuevo
# Processing Record 29 of Set 12 | seka
# Processing Record 30 of Set 12 | bel ombre
# Processing Record 31 of Set 12 | kalmunai
# Processing Record 32 of Set 12 | jiazi
# Processing Record 33 of Set 12 | hadibu
# Processing Record 34 of Set 12 | lubao
# Processing Record 35 of Set 12 | kerman
# Processing Record 36 of Set 12 | contamana
# Processing Record 37 of Set 12 | mirnyy
# Processing Record 38 of Set 12 | ati
# Processing Record 39 of Set 12 | narathiwat
# Processing Record 40 of Set 12 | torghay
# Processing Record 41 of Set 12 | mocksville
# Processing Record 42 of Set 12 | diebougou
# Processing Record 43 of Set 12 | shalqar
# Processing Record 44 of Set 12 | salekhard
# Processing Record 45 of Set 12 | capulin
# Processing Record 46 of Set 12 | fort bragg
# Processing Record 47 of Set 12 | berdigestyakh
# Processing Record 48 of Set 12 | boa vista
# Processing Record 49 of Set 12 | howrah
# Processing Record 0 of Set 13 | port augusta
# Processing Record 1 of Set 13 | bargara
# City not found. Skipping...
# Processing Record 2 of Set 13 | tapa
# Processing Record 3 of Set 13 | ust'-charyshskaya pristan'
# Processing Record 4 of Set 13 | port moresby
# Processing Record 5 of Set 13 | camilla
# Processing Record 6 of Set 13 | bay shore
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              perth -31.9333  115.8333     16.82        91           0
# 1           waitangi -43.9535 -176.5597     10.46        78          53
# 2  port-aux-francais -49.3500   70.2167      7.02        96          99
# 3       sodra sandby  56.5667   16.6167      6.05        83          37
# 4     port elizabeth -33.9180   25.5701     18.39        77          40
#
#    Wind Speed Country        Date
# 0        2.06      AU  1714148102
# 1        2.24      NZ  1714148162
# 2       11.18      TF  1714148161
# 3        4.03      SE  1714148659
# 4        3.60      ZA  1714148171

# %%
# Export the City_Data into a csv
from pathlib import Path  
filepath = Path('python-api-challenge/output_data/cities.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)       
city_data_df.to_csv("python-api-challenge/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("python-api-challenge/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                    perth -31.9333  115.8333     16.82        91           0
# 1                 waitangi -43.9535 -176.5597     10.46        78          53
# 2        port-aux-francais -49.3500   70.2167      7.02        96          99
# 3             sodra sandby  56.5667   16.6167      6.05        83          37
# 4           port elizabeth -33.9180   25.5701     18.39        77          40
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      AU  1714148102
# 1              2.24      NZ  1714148162
# 2             11.18      TF  1714148161
# 3              4.03      SE  1714148659
# 4              3.60      ZA  1714148171

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
temp = city_data_df['Max Temp']

x = latitude
y = temp
plt.scatter(x,y)
plt.title('City Max Latitude vs. Temperature (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
date = city_data_df['Date'].max()
latitude = city_data_df['Lat']
humidity = city_data_df['Humidity']
x = latitude
y = humidity
plt.scatter(x,y)
plt.title('City Max Latitude vs. Humidity (2024-04-26)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("python-api-challenge/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
