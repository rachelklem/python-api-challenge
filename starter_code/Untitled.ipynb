# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %%
# Set the API base URL
base_url = "https://api.openweathermap.org/data/2.5/weather"
url = f"{base_url}?q={city}&appid={weather_api_key}&units=imperial"
print(url)

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0


    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
     # Log the URL and set number
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Extract out max temp humidity and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the city info into the city data list
        city_data.append({
            "City" :city,
            "Lat" :city_lat,
            "Lng" :city_lng,
            "Max Temp" :city_max_temp,
            "Humidity" :city_humidity,
            "Cloudiness" :city_clouds,
            "Windspeed" :city_wind,
            "Country" :city_country,
            "Date" :city_date  
        })
    except:
        print("City not found. Skipping ...")
        pass
    # Indicate that data loading is complete
        print("-----------------------")
        print("Data Retrieval Complete")
        print("-----------------------")
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=whakatane&appid=5fb9c171f52256217b69d0b00b3fd60e&units=imperial
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | la passe
# Processing Record 6 of Set 1 | la passe
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | blackmans bay
# Processing Record 10 of Set 1 | blackmans bay
# Processing Record 11 of Set 1 | pacific grove
# Processing Record 12 of Set 1 | pacific grove
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | katsuura
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | selfoss
# Processing Record 18 of Set 1 | selfoss
# Processing Record 19 of Set 1 | netrakona
# Processing Record 20 of Set 1 | netrakona
# Processing Record 21 of Set 1 | launceston
# Processing Record 22 of Set 1 | launceston
# Processing Record 23 of Set 1 | stanley
# Processing Record 24 of Set 1 | stanley
# Processing Record 25 of Set 1 | guiuan
# Processing Record 26 of Set 1 | guiuan
# Processing Record 27 of Set 1 | salalah
# Processing Record 28 of Set 1 | salalah
# Processing Record 29 of Set 1 | aasiaat
# Processing Record 30 of Set 1 | aasiaat
# Processing Record 31 of Set 1 | inhambane
# Processing Record 32 of Set 1 | inhambane
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | adamstown
# Processing Record 36 of Set 1 | adamstown
# Processing Record 37 of Set 1 | sikonge
# Processing Record 38 of Set 1 | sikonge
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | tchintabaraden
# Processing Record 42 of Set 1 | tchintabaraden
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | portland
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | west island
# Processing Record 50 of Set 1 | west island
# Processing Record 51 of Set 1 | bethel
# Processing Record 52 of Set 1 | bethel
# Processing Record 53 of Set 1 | ajaccio
# Processing Record 54 of Set 1 | ajaccio
# Processing Record 55 of Set 1 | nemuro
# Processing Record 56 of Set 1 | nemuro
# Processing Record 57 of Set 1 | olonkinbyen
# Processing Record 58 of Set 1 | olonkinbyen
# Processing Record 59 of Set 1 | ola
# Processing Record 60 of Set 1 | ola
# Processing Record 61 of Set 1 | puerto natales
# Processing Record 62 of Set 1 | puerto natales
# Processing Record 63 of Set 1 | crane
# Processing Record 64 of Set 1 | crane
# Processing Record 65 of Set 1 | luderitz
# Processing Record 66 of Set 1 | luderitz
# Processing Record 67 of Set 1 | faya-largeau
# Processing Record 68 of Set 1 | faya-largeau
# Processing Record 69 of Set 1 | punta arenas
# Processing Record 70 of Set 1 | punta arenas
# Processing Record 71 of Set 1 | maple glen
# Processing Record 72 of Set 1 | maple glen
# Processing Record 73 of Set 1 | kavalerovo
# Processing Record 74 of Set 1 | kavalerovo
# Processing Record 75 of Set 1 | tongliao
# Processing Record 76 of Set 1 | tongliao
# Processing Record 77 of Set 1 | badger
# Processing Record 78 of Set 1 | badger
# Processing Record 79 of Set 1 | midelt
# Processing Record 80 of Set 1 | midelt
# Processing Record 81 of Set 1 | tazacorte
# Processing Record 82 of Set 1 | tazacorte
# Processing Record 83 of Set 1 | ivdel'
# Processing Record 84 of Set 1 | ivdel'
# Processing Record 85 of Set 1 | sonoita
# Processing Record 86 of Set 1 | sonoita
# Processing Record 87 of Set 1 | constantia
# Processing Record 88 of Set 1 | constantia
# Processing Record 89 of Set 1 | santyoku
# Processing Record 90 of Set 1 | santyoku
# Processing Record 91 of Set 1 | sinabang
# Processing Record 92 of Set 1 | sinabang
# Processing Record 93 of Set 1 | puerto deseado
# Processing Record 94 of Set 1 | puerto deseado
# Processing Record 95 of Set 1 | tromso
# Processing Record 96 of Set 1 | tromso
# Processing Record 97 of Set 1 | edinburgh of the seven seas
# Processing Record 98 of Set 1 | edinburgh of the seven seas
# Processing Record 99 of Set 1 | antofagasta
# Processing Record 100 of Set 1 | antofagasta
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | vila velha
# Processing Record 3 of Set 2 | vila velha
# Processing Record 4 of Set 2 | oakdale
# Processing Record 5 of Set 2 | oakdale
# Processing Record 6 of Set 2 | labrador city
# Processing Record 7 of Set 2 | labrador city
# Processing Record 8 of Set 2 | san patricio
# Processing Record 9 of Set 2 | san patricio
# Processing Record 10 of Set 2 | ixtapa
# Processing Record 11 of Set 2 | ixtapa
# Processing Record 12 of Set 2 | utrik
# Processing Record 13 of Set 2 | utrik
# Processing Record 14 of Set 2 | tsiombe
# Processing Record 15 of Set 2 | tsiombe
# Processing Record 16 of Set 2 | loango
# Processing Record 17 of Set 2 | loango
# Processing Record 18 of Set 2 | el paraiso
# Processing Record 19 of Set 2 | el paraiso
# Processing Record 20 of Set 2 | allapalli
# Processing Record 21 of Set 2 | allapalli
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | champerico
# Processing Record 25 of Set 2 | champerico
# Processing Record 26 of Set 2 | melrose
# Processing Record 27 of Set 2 | melrose
# Processing Record 28 of Set 2 | tortoli
# Processing Record 29 of Set 2 | tortoli
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | ushuaia
# Processing Record 32 of Set 2 | hammerfest
# Processing Record 33 of Set 2 | hammerfest
# Processing Record 34 of Set 2 | ma'rib
# Processing Record 35 of Set 2 | ma'rib
# Processing Record 36 of Set 2 | faro
# Processing Record 37 of Set 2 | faro
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | talnakh
# Processing Record 40 of Set 2 | mahdia
# Processing Record 41 of Set 2 | mahdia
# Processing Record 42 of Set 2 | thanh hoa
# Processing Record 43 of Set 2 | thanh hoa
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | geraldton
# Processing Record 46 of Set 2 | fada
# Processing Record 47 of Set 2 | fada
# Processing Record 48 of Set 2 | vorgashor
# Processing Record 49 of Set 2 | vorgashor
# Processing Record 50 of Set 2 | tanjung pandan
# Processing Record 51 of Set 2 | tanjung pandan
# Processing Record 52 of Set 2 | isafjordur
# Processing Record 53 of Set 2 | isafjordur
# Processing Record 54 of Set 2 | hamilton
# Processing Record 55 of Set 2 | hamilton
# Processing Record 56 of Set 2 | leer
# Processing Record 57 of Set 2 | leer
# Processing Record 58 of Set 2 | al ghayzah
# Processing Record 59 of Set 2 | al ghayzah
# Processing Record 60 of Set 2 | gadzhiyevo
# Processing Record 61 of Set 2 | gadzhiyevo
# Processing Record 62 of Set 2 | fuvahmulah
# Processing Record 63 of Set 2 | fuvahmulah
# Processing Record 64 of Set 2 | puerto baquerizo moreno
# Processing Record 65 of Set 2 | puerto baquerizo moreno
# Processing Record 66 of Set 2 | howard springs
# Processing Record 67 of Set 2 | howard springs
# Processing Record 68 of Set 2 | puerto ayora
# Processing Record 69 of Set 2 | puerto ayora
# Processing Record 70 of Set 2 | bredasdorp
# Processing Record 71 of Set 2 | bredasdorp
# Processing Record 72 of Set 2 | inongo
# Processing Record 73 of Set 2 | inongo
# Processing Record 74 of Set 2 | 'ohonua
# Processing Record 75 of Set 2 | 'ohonua
# Processing Record 76 of Set 2 | mejit
# Processing Record 77 of Set 2 | mejit
# Processing Record 78 of Set 2 | sol'-iletsk
# Processing Record 79 of Set 2 | sol'-iletsk
# Processing Record 80 of Set 2 | prince rupert
# Processing Record 81 of Set 2 | prince rupert
# Processing Record 82 of Set 2 | merritt
# Processing Record 83 of Set 2 | merritt
# Processing Record 84 of Set 2 | qarazhal
# Processing Record 85 of Set 2 | qarazhal
# Processing Record 86 of Set 2 | khorixas
# Processing Record 87 of Set 2 | khorixas
# Processing Record 88 of Set 2 | bilibino
# Processing Record 89 of Set 2 | bilibino
# Processing Record 90 of Set 2 | talcahuano
# Processing Record 91 of Set 2 | talcahuano
# Processing Record 92 of Set 2 | pierre
# Processing Record 93 of Set 2 | pierre
# Processing Record 94 of Set 2 | margaret river
# Processing Record 95 of Set 2 | margaret river
# Processing Record 96 of Set 2 | susuman
# Processing Record 97 of Set 2 | susuman
# Processing Record 98 of Set 2 | anadyr
# Processing Record 99 of Set 2 | anadyr
# Processing Record 0 of Set 3 | nar'yan-mar
# Processing Record 1 of Set 3 | nar'yan-mar
# Processing Record 2 of Set 3 | vadso
# Processing Record 3 of Set 3 | vadso
# Processing Record 4 of Set 3 | holualoa
# Processing Record 5 of Set 3 | holualoa
# Processing Record 6 of Set 3 | wotho
# Processing Record 7 of Set 3 | wotho
# Processing Record 8 of Set 3 | tranovaho
# Processing Record 9 of Set 3 | tranovaho
# Processing Record 10 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 11 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 3 | la sarre
# Processing Record 13 of Set 3 | la sarre
# Processing Record 14 of Set 3 | broken hill
# Processing Record 15 of Set 3 | broken hill
# Processing Record 16 of Set 3 | selma
# Processing Record 17 of Set 3 | selma
# Processing Record 18 of Set 3 | mirny
# Processing Record 19 of Set 3 | mirny
# Processing Record 20 of Set 3 | tazovsky
# Processing Record 21 of Set 3 | tazovsky
# Processing Record 22 of Set 3 | whitehorse
# Processing Record 23 of Set 3 | whitehorse
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | kachug
# Processing Record 29 of Set 3 | kachug
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | pangody
# Processing Record 33 of Set 3 | pangody
# Processing Record 34 of Set 3 | coahuayana de hidalgo
# Processing Record 35 of Set 3 | coahuayana de hidalgo
# Processing Record 36 of Set 3 | bairnsdale
# Processing Record 37 of Set 3 | bairnsdale
# Processing Record 38 of Set 3 | fort bragg
# Processing Record 39 of Set 3 | fort bragg
# Processing Record 40 of Set 3 | mynamaki
# Processing Record 41 of Set 3 | mynamaki
# Processing Record 42 of Set 3 | akrehamn
# Processing Record 43 of Set 3 | akrehamn
# Processing Record 44 of Set 3 | bamboo flat
# Processing Record 45 of Set 3 | bamboo flat
# Processing Record 46 of Set 3 | keflavik
# Processing Record 47 of Set 3 | keflavik
# Processing Record 48 of Set 3 | bodo
# Processing Record 49 of Set 3 | bodo
# Processing Record 50 of Set 3 | brookings
# Processing Record 51 of Set 3 | brookings
# Processing Record 52 of Set 3 | blairgowrie
# Processing Record 53 of Set 3 | blairgowrie
# Processing Record 54 of Set 3 | tolanaro
# Processing Record 55 of Set 3 | tolanaro
# Processing Record 56 of Set 3 | avarua
# Processing Record 57 of Set 3 | avarua
# Processing Record 58 of Set 3 | kingscliff
# Processing Record 59 of Set 3 | kingscliff
# Processing Record 60 of Set 3 | olyokminsk
# Processing Record 61 of Set 3 | olyokminsk
# Processing Record 62 of Set 3 | georgetown
# Processing Record 63 of Set 3 | georgetown
# Processing Record 64 of Set 3 | pionerskiy
# Processing Record 65 of Set 3 | pionerskiy
# Processing Record 66 of Set 3 | invercargill
# Processing Record 67 of Set 3 | invercargill
# Processing Record 68 of Set 3 | terme
# Processing Record 69 of Set 3 | terme
# Processing Record 70 of Set 3 | vingt cinq
# Processing Record 71 of Set 3 | vingt cinq
# Processing Record 72 of Set 3 | kandahar
# Processing Record 73 of Set 3 | kandahar
# Processing Record 74 of Set 3 | kingston
# Processing Record 75 of Set 3 | kingston
# Processing Record 76 of Set 3 | puerto san jose
# Processing Record 77 of Set 3 | puerto san jose
# Processing Record 78 of Set 3 | iqaluit
# Processing Record 79 of Set 3 | iqaluit
# Processing Record 80 of Set 3 | papatowai
# Processing Record 81 of Set 3 | papatowai
# Processing Record 82 of Set 3 | temiskaming shores
# Processing Record 83 of Set 3 | temiskaming shores
# Processing Record 84 of Set 3 | maasim
# Processing Record 85 of Set 3 | maasim
# Processing Record 86 of Set 3 | san jose village
# Processing Record 87 of Set 3 | san jose village
# Processing Record 88 of Set 3 | raja
# Processing Record 89 of Set 3 | raja
# Processing Record 90 of Set 3 | mana
# Processing Record 91 of Set 3 | mana
# Processing Record 92 of Set 3 | arteche
# Processing Record 93 of Set 3 | arteche
# Processing Record 94 of Set 3 | sattahip
# Processing Record 95 of Set 3 | sattahip
# Processing Record 96 of Set 3 | labuan
# Processing Record 97 of Set 3 | labuan
# Processing Record 98 of Set 3 | roma
# Processing Record 99 of Set 3 | roma
# Processing Record 0 of Set 4 | bom jesus
# Processing Record 1 of Set 4 | bom jesus
# Processing Record 2 of Set 4 | itaituba
# Processing Record 3 of Set 4 | itaituba
# Processing Record 4 of Set 4 | zharkent
# Processing Record 5 of Set 4 | zharkent
# Processing Record 6 of Set 4 | afaahiti
# Processing Record 7 of Set 4 | afaahiti
# Processing Record 8 of Set 4 | chiredzi
# Processing Record 9 of Set 4 | chiredzi
# Processing Record 10 of Set 4 | qaqortoq
# Processing Record 11 of Set 4 | qaqortoq
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | kolokani
# Processing Record 17 of Set 4 | kolokani
# Processing Record 18 of Set 4 | polyarnyy
# Processing Record 19 of Set 4 | polyarnyy
# Processing Record 20 of Set 4 | lebu
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | zyryanskoye
# Processing Record 23 of Set 4 | zyryanskoye
# Processing Record 24 of Set 4 | bloomington
# Processing Record 25 of Set 4 | bloomington
# Processing Record 26 of Set 4 | minas de marcona
# Processing Record 27 of Set 4 | minas de marcona
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | uturoa
# Processing Record 31 of Set 4 | uturoa
# Processing Record 32 of Set 4 | codrington
# Processing Record 33 of Set 4 | codrington
# Processing Record 34 of Set 4 | na mom
# Processing Record 35 of Set 4 | na mom
# Processing Record 36 of Set 4 | kapuskasing
# Processing Record 37 of Set 4 | kapuskasing
# Processing Record 38 of Set 4 | suva
# Processing Record 39 of Set 4 | suva
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | selogiri
# Processing Record 43 of Set 4 | selogiri
# Processing Record 44 of Set 4 | aktobe
# Processing Record 45 of Set 4 | aktobe
# Processing Record 46 of Set 4 | kailua-kona
# Processing Record 47 of Set 4 | kailua-kona
# Processing Record 48 of Set 4 | lata
# Processing Record 49 of Set 4 | lata
# Processing Record 50 of Set 4 | kudahuvadhoo
# Processing Record 51 of Set 4 | kudahuvadhoo
# Processing Record 52 of Set 4 | acarau
# Processing Record 53 of Set 4 | acarau
# Processing Record 54 of Set 4 | alesund
# Processing Record 55 of Set 4 | alesund
# Processing Record 56 of Set 4 | jamestown
# Processing Record 57 of Set 4 | jamestown
# Processing Record 58 of Set 4 | thompson
# Processing Record 59 of Set 4 | thompson
# Processing Record 60 of Set 4 | adigrat
# Processing Record 61 of Set 4 | adigrat
# Processing Record 62 of Set 4 | levuka
# Processing Record 63 of Set 4 | levuka
# Processing Record 64 of Set 4 | novodvinsk
# Processing Record 65 of Set 4 | novodvinsk
# Processing Record 66 of Set 4 | wadsworth
# Processing Record 67 of Set 4 | wadsworth
# Processing Record 68 of Set 4 | puerto san carlos
# Processing Record 69 of Set 4 | puerto san carlos
# Processing Record 70 of Set 4 | arraial do cabo
# Processing Record 71 of Set 4 | arraial do cabo
# Processing Record 72 of Set 4 | taiohae
# Processing Record 73 of Set 4 | taiohae
# Processing Record 74 of Set 4 | puerto colombia
# Processing Record 75 of Set 4 | puerto colombia
# Processing Record 76 of Set 4 | pratapgarh
# Processing Record 77 of Set 4 | pratapgarh
# Processing Record 78 of Set 4 | cabedelo
# Processing Record 79 of Set 4 | cabedelo
# Processing Record 80 of Set 4 | sarupathar
# Processing Record 81 of Set 4 | sarupathar
# Processing Record 82 of Set 4 | gangtok
# Processing Record 83 of Set 4 | gangtok
# Processing Record 84 of Set 4 | akureyri
# Processing Record 85 of Set 4 | akureyri
# Processing Record 86 of Set 4 | ta`u
# Processing Record 87 of Set 4 | ta`u
# Processing Record 88 of Set 4 | tynda
# Processing Record 89 of Set 4 | tynda
# Processing Record 90 of Set 4 | egilsstadir
# Processing Record 91 of Set 4 | egilsstadir
# Processing Record 92 of Set 4 | nova sintra
# Processing Record 93 of Set 4 | nova sintra
# Processing Record 94 of Set 4 | tijuana
# Processing Record 95 of Set 4 | tijuana
# Processing Record 96 of Set 4 | saipan
# Processing Record 97 of Set 4 | saipan
# Processing Record 98 of Set 4 | ilulissat
# Processing Record 99 of Set 4 | ilulissat
# Processing Record 0 of Set 5 | bengkulu
# Processing Record 1 of Set 5 | bengkulu
# Processing Record 2 of Set 5 | happy valley-goose bay
# Processing Record 3 of Set 5 | happy valley-goose bay
# Processing Record 4 of Set 5 | college
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | karratha
# Processing Record 7 of Set 5 | karratha
# Processing Record 8 of Set 5 | auki
# Processing Record 9 of Set 5 | auki
# Processing Record 10 of Set 5 | laguna
# Processing Record 11 of Set 5 | laguna
# Processing Record 12 of Set 5 | chitipa
# Processing Record 13 of Set 5 | chitipa
# Processing Record 14 of Set 5 | papao
# Processing Record 15 of Set 5 | papao
# Processing Record 16 of Set 5 | axim
# Processing Record 17 of Set 5 | axim
# Processing Record 18 of Set 5 | junin de los andes
# Processing Record 19 of Set 5 | junin de los andes
# Processing Record 20 of Set 5 | hermosillo
# Processing Record 21 of Set 5 | hermosillo
# Processing Record 22 of Set 5 | mawlaik
# Processing Record 23 of Set 5 | mawlaik
# Processing Record 24 of Set 5 | sarangani
# Processing Record 25 of Set 5 | sarangani
# Processing Record 26 of Set 5 | lihue
# Processing Record 27 of Set 5 | lihue
# Processing Record 28 of Set 5 | jaguaruna
# Processing Record 29 of Set 5 | jaguaruna
# Processing Record 30 of Set 5 | udachny
# Processing Record 31 of Set 5 | udachny
# Processing Record 32 of Set 5 | port mathurin
# Processing Record 33 of Set 5 | port mathurin
# Processing Record 34 of Set 5 | colonia
# Processing Record 35 of Set 5 | colonia
# Processing Record 36 of Set 5 | syriam
# Processing Record 37 of Set 5 | syriam
# Processing Record 38 of Set 5 | chonchi
# Processing Record 39 of Set 5 | chonchi
# Processing Record 40 of Set 5 | mount pearl
# Processing Record 41 of Set 5 | mount pearl
# Processing Record 42 of Set 5 | astara
# Processing Record 43 of Set 5 | astara
# Processing Record 44 of Set 5 | al lagowa
# Processing Record 45 of Set 5 | al lagowa
# Processing Record 46 of Set 5 | kiunga
# Processing Record 47 of Set 5 | kiunga
# Processing Record 48 of Set 5 | wailua homesteads
# Processing Record 49 of Set 5 | wailua homesteads
# Processing Record 50 of Set 5 | jalai nur
# Processing Record 51 of Set 5 | jalai nur
# Processing Record 52 of Set 5 | naze
# Processing Record 53 of Set 5 | naze
# Processing Record 54 of Set 5 | senador jose porfirio
# Processing Record 55 of Set 5 | senador jose porfirio
# Processing Record 56 of Set 5 | hadibu
# Processing Record 57 of Set 5 | hadibu
# Processing Record 58 of Set 5 | ust-tsilma
# Processing Record 59 of Set 5 | ust-tsilma
# Processing Record 60 of Set 5 | sangmelima
# Processing Record 61 of Set 5 | sangmelima
# Processing Record 62 of Set 5 | aguada de pasajeros
# Processing Record 63 of Set 5 | aguada de pasajeros
# Processing Record 64 of Set 5 | terekeka
# Processing Record 65 of Set 5 | terekeka
# Processing Record 66 of Set 5 | carnarvon
# Processing Record 67 of Set 5 | carnarvon
# Processing Record 68 of Set 5 | baiti
# Processing Record 69 of Set 5 | baiti
# Processing Record 70 of Set 5 | trairi
# Processing Record 71 of Set 5 | trairi
# Processing Record 72 of Set 5 | yatou
# Processing Record 73 of Set 5 | yatou
# Processing Record 74 of Set 5 | touros
# Processing Record 75 of Set 5 | touros
# Processing Record 76 of Set 5 | posto fiscal rolim de moura
# Processing Record 77 of Set 5 | posto fiscal rolim de moura
# Processing Record 78 of Set 5 | palikir - national government center
# Processing Record 79 of Set 5 | palikir - national government center
# Processing Record 80 of Set 5 | knittelfeld
# Processing Record 81 of Set 5 | knittelfeld
# Processing Record 82 of Set 5 | keren
# Processing Record 83 of Set 5 | keren
# Processing Record 84 of Set 5 | muisne
# Processing Record 85 of Set 5 | muisne
# Processing Record 86 of Set 5 | port macquarie
# Processing Record 87 of Set 5 | port macquarie
# Processing Record 88 of Set 5 | qianzhou
# Processing Record 89 of Set 5 | qianzhou
# Processing Record 90 of Set 5 | kievka
# Processing Record 91 of Set 5 | kievka
# Processing Record 92 of Set 5 | strezhevoy
# Processing Record 93 of Set 5 | strezhevoy
# Processing Record 94 of Set 5 | noumea
# Processing Record 95 of Set 5 | noumea
# Processing Record 96 of Set 5 | fort morgan
# Processing Record 97 of Set 5 | fort morgan
# Processing Record 98 of Set 5 | ust-nera
# Processing Record 99 of Set 5 | ust-nera
# Processing Record 0 of Set 6 | qui nhon
# Processing Record 1 of Set 6 | qui nhon
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | east london
# Processing Record 4 of Set 6 | the pas
# Processing Record 5 of Set 6 | the pas
# Processing Record 6 of Set 6 | klyuchi
# Processing Record 7 of Set 6 | klyuchi
# Processing Record 8 of Set 6 | okha
# Processing Record 9 of Set 6 | okha
# Processing Record 10 of Set 6 | bodden town
# Processing Record 11 of Set 6 | bodden town
# Processing Record 12 of Set 6 | salmon arm
# Processing Record 13 of Set 6 | salmon arm
# Processing Record 14 of Set 6 | ouesso
# Processing Record 15 of Set 6 | ouesso
# Processing Record 16 of Set 6 | ciudad melchor muzquiz
# Processing Record 17 of Set 6 | ciudad melchor muzquiz
# Processing Record 18 of Set 6 | quepos
# Processing Record 19 of Set 6 | quepos
# Processing Record 20 of Set 6 | alagapuram
# Processing Record 21 of Set 6 | alagapuram
# Processing Record 22 of Set 6 | valparaiso
# Processing Record 23 of Set 6 | valparaiso
# Processing Record 24 of Set 6 | chui
# Processing Record 25 of Set 6 | chui
# Processing Record 26 of Set 6 | atafu village
# Processing Record 27 of Set 6 | atafu village
# Processing Record 28 of Set 6 | cairns city
# Processing Record 29 of Set 6 | cairns city
# Processing Record 30 of Set 6 | kayangel
# Processing Record 31 of Set 6 | kayangel
# Processing Record 32 of Set 6 | gizo
# Processing Record 33 of Set 6 | gizo
# Processing Record 34 of Set 6 | aiken
# Processing Record 35 of Set 6 | aiken
# Processing Record 36 of Set 6 | kodiak
# Processing Record 37 of Set 6 | kodiak
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | paramonga
# Processing Record 41 of Set 6 | paramonga
# Processing Record 42 of Set 6 | werota
# Processing Record 43 of Set 6 | werota
# Processing Record 44 of Set 6 | fale old settlement
# Processing Record 45 of Set 6 | fale old settlement
# Processing Record 46 of Set 6 | kill devil hills
# Processing Record 47 of Set 6 | kill devil hills
# Processing Record 48 of Set 6 | iskateley
# Processing Record 49 of Set 6 | iskateley
# Processing Record 50 of Set 6 | hargeysa
# Processing Record 51 of Set 6 | hargeysa
# Processing Record 52 of Set 6 | fortaleza
# Processing Record 53 of Set 6 | fortaleza
# Processing Record 54 of Set 6 | dronero
# Processing Record 55 of Set 6 | dronero
# Processing Record 56 of Set 6 | lukoyanov
# Processing Record 57 of Set 6 | lukoyanov
# Processing Record 58 of Set 6 | laibin
# Processing Record 59 of Set 6 | laibin
# Processing Record 60 of Set 6 | severo-yeniseyskiy
# Processing Record 61 of Set 6 | severo-yeniseyskiy
# Processing Record 62 of Set 6 | fort-shevchenko
# Processing Record 63 of Set 6 | fort-shevchenko
# Processing Record 64 of Set 6 | bodaybo
# Processing Record 65 of Set 6 | bodaybo
# Processing Record 66 of Set 6 | tanrake village
# Processing Record 67 of Set 6 | tanrake village
# Processing Record 68 of Set 6 | guerrero negro
# Processing Record 69 of Set 6 | guerrero negro
# Processing Record 70 of Set 6 | illizi
# Processing Record 71 of Set 6 | illizi
# Processing Record 72 of Set 6 | kissidougou
# Processing Record 73 of Set 6 | kissidougou
# Processing Record 74 of Set 6 | nantucket
# Processing Record 75 of Set 6 | nantucket
# Processing Record 76 of Set 6 | sonsorol village
# Processing Record 77 of Set 6 | sonsorol village
# Processing Record 78 of Set 6 | kruisfontein
# Processing Record 79 of Set 6 | kruisfontein
# Processing Record 80 of Set 6 | porto velho
# Processing Record 81 of Set 6 | porto velho
# Processing Record 82 of Set 6 | kotido
# Processing Record 83 of Set 6 | kotido
# Processing Record 84 of Set 6 | alta
# Processing Record 85 of Set 6 | alta
# Processing Record 86 of Set 6 | dakhla
# Processing Record 87 of Set 6 | dakhla
# Processing Record 88 of Set 6 | uchaly
# Processing Record 89 of Set 6 | uchaly
# Processing Record 90 of Set 6 | port saint john's
# Processing Record 91 of Set 6 | port saint john's
# Processing Record 92 of Set 6 | mount gambier
# Processing Record 93 of Set 6 | mount gambier
# Processing Record 94 of Set 6 | remire-montjoly
# Processing Record 95 of Set 6 | remire-montjoly
# Processing Record 96 of Set 6 | grand falls-windsor
# Processing Record 97 of Set 6 | grand falls-windsor
# Processing Record 98 of Set 6 | czerwonak
# Processing Record 99 of Set 6 | czerwonak
# Processing Record 0 of Set 7 | vitkov
# Processing Record 1 of Set 7 | vitkov
# Processing Record 2 of Set 7 | praia da vitoria
# Processing Record 3 of Set 7 | praia da vitoria
# Processing Record 4 of Set 7 | akankpa
# Processing Record 5 of Set 7 | akankpa
# Processing Record 6 of Set 7 | cidade velha
# Processing Record 7 of Set 7 | cidade velha
# Processing Record 8 of Set 7 | whangarei
# Processing Record 9 of Set 7 | whangarei
# Processing Record 10 of Set 7 | hawaiian paradise park
# Processing Record 11 of Set 7 | hawaiian paradise park
# Processing Record 12 of Set 7 | guanica
# Processing Record 13 of Set 7 | guanica
# Processing Record 14 of Set 7 | rio grande
# Processing Record 15 of Set 7 | rio grande
# Processing Record 16 of Set 7 | peniche
# Processing Record 17 of Set 7 | peniche
# Processing Record 18 of Set 7 | chuguyevka
# Processing Record 19 of Set 7 | chuguyevka
# Processing Record 20 of Set 7 | saint-philippe
# Processing Record 21 of Set 7 | saint-philippe
# Processing Record 22 of Set 7 | tobi village
# Processing Record 23 of Set 7 | tobi village
# Processing Record 24 of Set 7 | penzance
# Processing Record 25 of Set 7 | penzance
# Processing Record 26 of Set 7 | kaniv
# Processing Record 27 of Set 7 | kaniv
# Processing Record 28 of Set 7 | nova xavantina
# Processing Record 29 of Set 7 | nova xavantina
# Processing Record 30 of Set 7 | corinto
# Processing Record 31 of Set 7 | corinto
# Processing Record 32 of Set 7 | pattan
# Processing Record 33 of Set 7 | pattan
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | lompoc
# Processing Record 36 of Set 7 | prado
# Processing Record 37 of Set 7 | prado
# Processing Record 38 of Set 7 | linxia chengguanzhen
# Processing Record 39 of Set 7 | linxia chengguanzhen
# Processing Record 40 of Set 7 | rosetta
# Processing Record 41 of Set 7 | rosetta
# Processing Record 42 of Set 7 | araci
# Processing Record 43 of Set 7 | araci
# Processing Record 44 of Set 7 | chimore
# Processing Record 45 of Set 7 | chimore
# Processing Record 46 of Set 7 | el burgo de osma
# Processing Record 47 of Set 7 | el burgo de osma
# Processing Record 48 of Set 7 | sarh
# Processing Record 49 of Set 7 | sarh
# Processing Record 50 of Set 7 | franceville
# Processing Record 51 of Set 7 | franceville
# Processing Record 52 of Set 7 | zinjibar
# Processing Record 53 of Set 7 | zinjibar
# Processing Record 54 of Set 7 | hanceville
# Processing Record 55 of Set 7 | hanceville
# Processing Record 56 of Set 7 | tamanrasset
# Processing Record 57 of Set 7 | tamanrasset
# Processing Record 58 of Set 7 | tabuk
# Processing Record 59 of Set 7 | tabuk
# Processing Record 60 of Set 7 | antonio enes
# Processing Record 61 of Set 7 | antonio enes
# Processing Record 62 of Set 7 | hobyo
# Processing Record 63 of Set 7 | hobyo
# Processing Record 64 of Set 7 | oum hadjer
# Processing Record 65 of Set 7 | oum hadjer
# Processing Record 66 of Set 7 | san leone mose
# Processing Record 67 of Set 7 | san leone mose
# Processing Record 68 of Set 7 | castillos
# Processing Record 69 of Set 7 | castillos
# Processing Record 70 of Set 7 | queenstown
# Processing Record 71 of Set 7 | queenstown
# Processing Record 72 of Set 7 | aketi
# Processing Record 73 of Set 7 | aketi
# Processing Record 74 of Set 7 | balotra
# Processing Record 75 of Set 7 | balotra
# Processing Record 76 of Set 7 | kaa-khem
# Processing Record 77 of Set 7 | kaa-khem
# Processing Record 78 of Set 7 | sikeston
# Processing Record 79 of Set 7 | sikeston
# Processing Record 80 of Set 7 | manjeshvar
# Processing Record 81 of Set 7 | manjeshvar
# Processing Record 82 of Set 7 | lichtenburg
# Processing Record 83 of Set 7 | lichtenburg
# Processing Record 84 of Set 7 | sona
# Processing Record 85 of Set 7 | sona
# Processing Record 86 of Set 7 | pankovka
# Processing Record 87 of Set 7 | pankovka
# Processing Record 88 of Set 7 | alaior
# Processing Record 89 of Set 7 | alaior
# Processing Record 90 of Set 7 | crucecita
# Processing Record 91 of Set 7 | crucecita
# Processing Record 92 of Set 7 | alofi
# Processing Record 93 of Set 7 | alofi
# Processing Record 94 of Set 7 | siocon
# Processing Record 95 of Set 7 | siocon
# Processing Record 96 of Set 7 | smithers
# Processing Record 97 of Set 7 | smithers
# Processing Record 98 of Set 7 | luis correia
# Processing Record 99 of Set 7 | luis correia
# Processing Record 0 of Set 8 | antsiranana
# Processing Record 1 of Set 8 | antsiranana
# Processing Record 2 of Set 8 | macau
# Processing Record 3 of Set 8 | macau
# Processing Record 4 of Set 8 | san andros
# Processing Record 5 of Set 8 | san andros
# Processing Record 6 of Set 8 | la paz
# Processing Record 7 of Set 8 | la paz
# Processing Record 8 of Set 8 | st. john's
# Processing Record 9 of Set 8 | st. john's
# Processing Record 10 of Set 8 | barah
# Processing Record 11 of Set 8 | barah
# Processing Record 12 of Set 8 | nathdwara
# Processing Record 13 of Set 8 | nathdwara
# Processing Record 14 of Set 8 | berkeley
# Processing Record 15 of Set 8 | berkeley
# Processing Record 16 of Set 8 | cidreira
# Processing Record 17 of Set 8 | cidreira
# Processing Record 18 of Set 8 | chernyshevskiy
# Processing Record 19 of Set 8 | chernyshevskiy
# Processing Record 20 of Set 8 | trincomalee
# Processing Record 21 of Set 8 | trincomalee
# Processing Record 22 of Set 8 | alice springs
# Processing Record 23 of Set 8 | alice springs
# Processing Record 24 of Set 8 | jayapura
# Processing Record 25 of Set 8 | jayapura
# Processing Record 26 of Set 8 | kerikeri
# Processing Record 27 of Set 8 | kerikeri
# Processing Record 28 of Set 8 | khujner
# Processing Record 29 of Set 8 | khujner
# Processing Record 30 of Set 8 | ubari
# Processing Record 31 of Set 8 | ubari
# Processing Record 32 of Set 8 | new norfolk
# Processing Record 33 of Set 8 | new norfolk
# Processing Record 34 of Set 8 | george town
# Processing Record 35 of Set 8 | george town
# Processing Record 36 of Set 8 | miranda do douro
# Processing Record 37 of Set 8 | miranda do douro
# Processing Record 38 of Set 8 | quincy
# Processing Record 39 of Set 8 | quincy
# Processing Record 40 of Set 8 | hayma'
# Processing Record 41 of Set 8 | hayma'
# Processing Record 42 of Set 8 | biala podlaska
# Processing Record 43 of Set 8 | biala podlaska
# Processing Record 44 of Set 8 | aleg
# Processing Record 45 of Set 8 | aleg
# Processing Record 46 of Set 8 | tateyama
# Processing Record 47 of Set 8 | tateyama
# Processing Record 48 of Set 8 | bel ombre
# Processing Record 49 of Set 8 | bel ombre
# Processing Record 50 of Set 8 | urangan
# Processing Record 51 of Set 8 | urangan
# Processing Record 52 of Set 8 | khash
# Processing Record 53 of Set 8 | khash
# Processing Record 54 of Set 8 | san antonio de pale
# Processing Record 55 of Set 8 | san antonio de pale
# Processing Record 56 of Set 8 | khandyga
# Processing Record 57 of Set 8 | khandyga
# Processing Record 58 of Set 8 | yegorlykskaya
# Processing Record 59 of Set 8 | yegorlykskaya
# Processing Record 60 of Set 8 | kasongo-lunda
# Processing Record 61 of Set 8 | kasongo-lunda
# Processing Record 62 of Set 8 | mutare
# Processing Record 63 of Set 8 | mutare
# Processing Record 64 of Set 8 | arauca
# Processing Record 65 of Set 8 | arauca
# Processing Record 66 of Set 8 | sydney mines
# Processing Record 67 of Set 8 | sydney mines
# Processing Record 68 of Set 8 | okhotsk
# Processing Record 69 of Set 8 | okhotsk
# Processing Record 70 of Set 8 | hailey
# Processing Record 71 of Set 8 | hailey
# Processing Record 72 of Set 8 | pemangkat
# Processing Record 73 of Set 8 | pemangkat
# Processing Record 74 of Set 8 | xai-xai
# Processing Record 75 of Set 8 | xai-xai
# Processing Record 76 of Set 8 | menongue
# Processing Record 77 of Set 8 | menongue
# Processing Record 78 of Set 8 | dawei
# Processing Record 79 of Set 8 | dawei
# Processing Record 80 of Set 8 | brigantine
# Processing Record 81 of Set 8 | brigantine
# Processing Record 82 of Set 8 | joshimath
# Processing Record 83 of Set 8 | joshimath
# Processing Record 84 of Set 8 | freetown
# Processing Record 85 of Set 8 | freetown
# Processing Record 86 of Set 8 | priozersk
# Processing Record 87 of Set 8 | priozersk
# Processing Record 88 of Set 8 | rome
# Processing Record 89 of Set 8 | rome
# Processing Record 90 of Set 8 | tomok bolon
# Processing Record 91 of Set 8 | tomok bolon
# Processing Record 92 of Set 8 | hohhot
# Processing Record 93 of Set 8 | hohhot
# Processing Record 94 of Set 8 | mount isa
# Processing Record 95 of Set 8 | mount isa
# Processing Record 96 of Set 8 | dzhankoy
# Processing Record 97 of Set 8 | dzhankoy
# Processing Record 98 of Set 8 | dudinka
# Processing Record 99 of Set 8 | dudinka
# Processing Record 0 of Set 9 | casablanca
# Processing Record 1 of Set 9 | casablanca
# Processing Record 2 of Set 9 | tadmur
# Processing Record 3 of Set 9 | tadmur
# Processing Record 4 of Set 9 | paita
# Processing Record 5 of Set 9 | paita
# Processing Record 6 of Set 9 | nuuk
# Processing Record 7 of Set 9 | nuuk
# Processing Record 8 of Set 9 | christchurch
# Processing Record 9 of Set 9 | christchurch
# Processing Record 10 of Set 9 | ormara
# Processing Record 11 of Set 9 | ormara
# Processing Record 12 of Set 9 | port lincoln
# Processing Record 13 of Set 9 | port lincoln
# Processing Record 14 of Set 9 | felipe carrillo puerto
# Processing Record 15 of Set 9 | felipe carrillo puerto
# Processing Record 16 of Set 9 | jwaneng
# Processing Record 17 of Set 9 | jwaneng
# Processing Record 18 of Set 9 | planaltina
# Processing Record 19 of Set 9 | planaltina
# Processing Record 20 of Set 9 | kirakira
# Processing Record 21 of Set 9 | kirakira
# Processing Record 22 of Set 9 | kot samaba
# Processing Record 23 of Set 9 | kot samaba
# Processing Record 24 of Set 9 | doka
# Processing Record 25 of Set 9 | doka
# Processing Record 26 of Set 9 | soligalich
# Processing Record 27 of Set 9 | soligalich
# Processing Record 28 of Set 9 | kargopol'
# Processing Record 29 of Set 9 | kargopol'
# Processing Record 30 of Set 9 | aljezur
# Processing Record 31 of Set 9 | aljezur
# Processing Record 32 of Set 9 | machico
# Processing Record 33 of Set 9 | machico
# Processing Record 34 of Set 9 | avallon
# Processing Record 35 of Set 9 | avallon
# Processing Record 36 of Set 9 | imbituba
# Processing Record 37 of Set 9 | imbituba
# Processing Record 38 of Set 9 | shenjiamen
# Processing Record 39 of Set 9 | shenjiamen
# Processing Record 40 of Set 9 | la'ie
# Processing Record 41 of Set 9 | la'ie
# Processing Record 42 of Set 9 | la mira
# Processing Record 43 of Set 9 | la mira
# Processing Record 44 of Set 9 | tshabong
# Processing Record 45 of Set 9 | tshabong
# Processing Record 46 of Set 9 | bayanhongor
# Processing Record 47 of Set 9 | bayanhongor
# Processing Record 48 of Set 9 | palmer
# Processing Record 49 of Set 9 | palmer
# Processing Record 50 of Set 9 | bikenibeu village
# Processing Record 51 of Set 9 | bikenibeu village
# Processing Record 52 of Set 9 | pariaman
# Processing Record 53 of Set 9 | pariaman
# Processing Record 54 of Set 9 | lagunillas
# Processing Record 55 of Set 9 | lagunillas
# Processing Record 56 of Set 9 | vilyuysk
# Processing Record 57 of Set 9 | vilyuysk
# Processing Record 58 of Set 9 | leninskoye
# Processing Record 59 of Set 9 | leninskoye
# Processing Record 60 of Set 9 | weno
# Processing Record 61 of Set 9 | weno
# Processing Record 62 of Set 9 | misratah
# Processing Record 63 of Set 9 | misratah
# Processing Record 64 of Set 9 | altay
# Processing Record 65 of Set 9 | altay
# Processing Record 66 of Set 9 | leava
# Processing Record 67 of Set 9 | leava
# Processing Record 68 of Set 9 | vorkuta
# Processing Record 69 of Set 9 | vorkuta
# Processing Record 70 of Set 9 | luganville
# Processing Record 71 of Set 9 | luganville
# Processing Record 72 of Set 9 | villa madero
# Processing Record 73 of Set 9 | villa madero
# Processing Record 74 of Set 9 | yantzaza
# Processing Record 75 of Set 9 | yantzaza
# Processing Record 76 of Set 9 | ust'-barguzin
# Processing Record 77 of Set 9 | ust'-barguzin
# Processing Record 78 of Set 9 | ahau
# Processing Record 79 of Set 9 | ahau
# Processing Record 80 of Set 9 | vernon
# Processing Record 81 of Set 9 | vernon
# Processing Record 82 of Set 9 | saint-denis
# Processing Record 83 of Set 9 | saint-denis
# Processing Record 84 of Set 9 | borovskoy
# Processing Record 85 of Set 9 | borovskoy
# Processing Record 86 of Set 9 | claveria
# Processing Record 87 of Set 9 | claveria
# Processing Record 88 of Set 9 | teguise
# Processing Record 89 of Set 9 | teguise
# Processing Record 90 of Set 9 | nadym
# Processing Record 91 of Set 9 | nadym
# Processing Record 92 of Set 9 | zarechnyy
# Processing Record 93 of Set 9 | zarechnyy
# Processing Record 94 of Set 9 | forster
# Processing Record 95 of Set 9 | forster
# Processing Record 96 of Set 9 | ziro
# Processing Record 97 of Set 9 | ziro
# Processing Record 98 of Set 9 | al bardiyah
# Processing Record 99 of Set 9 | al bardiyah
# Processing Record 0 of Set 10 | nyurba
# Processing Record 1 of Set 10 | nyurba
# Processing Record 2 of Set 10 | douentza
# Processing Record 3 of Set 10 | douentza
# Processing Record 4 of Set 10 | vansada
# Processing Record 5 of Set 10 | vansada
# Processing Record 6 of Set 10 | mushie
# Processing Record 7 of Set 10 | mushie
# Processing Record 8 of Set 10 | dolores
# Processing Record 9 of Set 10 | dolores
# Processing Record 10 of Set 10 | atherton
# Processing Record 11 of Set 10 | atherton
# Processing Record 12 of Set 10 | wynyard
# Processing Record 13 of Set 10 | wynyard
# Processing Record 14 of Set 10 | altud
# Processing Record 15 of Set 10 | altud
# Processing Record 16 of Set 10 | at taj
# Processing Record 17 of Set 10 | at taj
# Processing Record 18 of Set 10 | saint-francois
# Processing Record 19 of Set 10 | saint-francois
# Processing Record 20 of Set 10 | el calafate
# Processing Record 21 of Set 10 | el calafate
# Processing Record 22 of Set 10 | eyl
# Processing Record 23 of Set 10 | eyl
# Processing Record 24 of Set 10 | ambovombe
# Processing Record 25 of Set 10 | ambovombe
# Processing Record 26 of Set 10 | carauari
# Processing Record 27 of Set 10 | carauari
# Processing Record 28 of Set 10 | stephenville
# Processing Record 29 of Set 10 | stephenville
# Processing Record 30 of Set 10 | iquique
# Processing Record 31 of Set 10 | iquique
# Processing Record 32 of Set 10 | pemba
# Processing Record 33 of Set 10 | pemba
# Processing Record 34 of Set 10 | tyukhtet
# Processing Record 35 of Set 10 | tyukhtet
# Processing Record 36 of Set 10 | kapa'a
# Processing Record 37 of Set 10 | kapa'a
# Processing Record 38 of Set 10 | salekhard
# Processing Record 39 of Set 10 | salekhard
# Processing Record 40 of Set 10 | bantay
# Processing Record 41 of Set 10 | bantay
# Processing Record 42 of Set 10 | samokov
# Processing Record 43 of Set 10 | samokov
# Processing Record 44 of Set 10 | gulf park estates
# Processing Record 45 of Set 10 | gulf park estates
# Processing Record 46 of Set 10 | mount pleasant
# Processing Record 47 of Set 10 | mount pleasant
# Processing Record 48 of Set 10 | kuta
# Processing Record 49 of Set 10 | kuta
# Processing Record 50 of Set 10 | kursenai
# Processing Record 51 of Set 10 | kursenai
# Processing Record 52 of Set 10 | ebon
# Processing Record 53 of Set 10 | ebon
# Processing Record 54 of Set 10 | kilindoni
# Processing Record 55 of Set 10 | kilindoni
# Processing Record 56 of Set 10 | uyuni
# Processing Record 57 of Set 10 | uyuni
# Processing Record 58 of Set 10 | neryungri
# Processing Record 59 of Set 10 | neryungri
# Processing Record 60 of Set 10 | hengchun
# Processing Record 61 of Set 10 | hengchun
# Processing Record 62 of Set 10 | new yekepa
# Processing Record 63 of Set 10 | new yekepa
# Processing Record 64 of Set 10 | christiansburg
# Processing Record 65 of Set 10 | christiansburg
# Processing Record 66 of Set 10 | lakatoro
# Processing Record 67 of Set 10 | lakatoro
# Processing Record 68 of Set 10 | cruzeiro do sul
# Processing Record 69 of Set 10 | cruzeiro do sul
# Processing Record 70 of Set 10 | zhezqazghan
# Processing Record 71 of Set 10 | zhezqazghan
# Processing Record 72 of Set 10 | mermoz boabab
# Processing Record 73 of Set 10 | mermoz boabab
# Processing Record 74 of Set 10 | maceio
# Processing Record 75 of Set 10 | maceio
# Processing Record 76 of Set 10 | cavelossim
# Processing Record 77 of Set 10 | cavelossim
# Processing Record 78 of Set 10 | hwange
# Processing Record 79 of Set 10 | hwange
# Processing Record 80 of Set 10 | novobureyskiy
# Processing Record 81 of Set 10 | novobureyskiy
# Processing Record 82 of Set 10 | mongo
# Processing Record 83 of Set 10 | mongo
# Processing Record 84 of Set 10 | shizunai-furukawacho
# Processing Record 85 of Set 10 | shizunai-furukawacho
# Processing Record 86 of Set 10 | callao
# Processing Record 87 of Set 10 | callao
# Processing Record 88 of Set 10 | manokwari
# Processing Record 89 of Set 10 | manokwari
# Processing Record 90 of Set 10 | ca mau
# Processing Record 91 of Set 10 | ca mau
# Processing Record 92 of Set 10 | kralendijk
# Processing Record 93 of Set 10 | kralendijk
# Processing Record 94 of Set 10 | kuching
# Processing Record 95 of Set 10 | kuching
# Processing Record 96 of Set 10 | sao joao da barra
# Processing Record 97 of Set 10 | sao joao da barra
# Processing Record 98 of Set 10 | farafangana
# Processing Record 99 of Set 10 | farafangana
# Processing Record 0 of Set 11 | chinsali
# Processing Record 1 of Set 11 | chinsali
# Processing Record 2 of Set 11 | tarfaya
# Processing Record 3 of Set 11 | tarfaya
# Processing Record 4 of Set 11 | slyudyanka
# Processing Record 5 of Set 11 | slyudyanka
# Processing Record 6 of Set 11 | vikulovo
# Processing Record 7 of Set 11 | vikulovo
# Processing Record 8 of Set 11 | agat village
# Processing Record 9 of Set 11 | agat village
# Processing Record 10 of Set 11 | dunedin
# Processing Record 11 of Set 11 | dunedin
# Processing Record 12 of Set 11 | kuqa
# Processing Record 13 of Set 11 | kuqa
# Processing Record 14 of Set 11 | askoy
# Processing Record 15 of Set 11 | askoy
# Processing Record 16 of Set 11 | puerto palomas
# Processing Record 17 of Set 11 | puerto palomas
# Processing Record 18 of Set 11 | ambon
# Processing Record 19 of Set 11 | ambon
# Processing Record 20 of Set 11 | clewiston
# Processing Record 21 of Set 11 | clewiston
# Processing Record 22 of Set 11 | spring creek
# Processing Record 23 of Set 11 | spring creek
# Processing Record 24 of Set 11 | globe
# Processing Record 25 of Set 11 | globe
# Processing Record 26 of Set 11 | isola di capo rizzuto
# Processing Record 27 of Set 11 | isola di capo rizzuto
# Processing Record 28 of Set 11 | newman
# Processing Record 29 of Set 11 | newman
# Processing Record 30 of Set 11 | usinsk
# Processing Record 31 of Set 11 | usinsk
# Processing Record 32 of Set 11 | tangi
# Processing Record 33 of Set 11 | tangi
# Processing Record 34 of Set 11 | enewetak
# Processing Record 35 of Set 11 | enewetak
# Processing Record 36 of Set 11 | barcelos
# Processing Record 37 of Set 11 | barcelos
# Processing Record 38 of Set 11 | revda
# Processing Record 39 of Set 11 | revda
# Processing Record 40 of Set 11 | senanga
# Processing Record 41 of Set 11 | senanga
# Processing Record 42 of Set 11 | sandnessjoen
# Processing Record 43 of Set 11 | sandnessjoen
# Processing Record 44 of Set 11 | murzuq
# Processing Record 45 of Set 11 | murzuq
# Processing Record 46 of Set 11 | isangel
# Processing Record 47 of Set 11 | isangel
# Processing Record 48 of Set 11 | krasnokamensk
# Processing Record 49 of Set 11 | krasnokamensk
# Processing Record 50 of Set 11 | pacasmayo
# Processing Record 51 of Set 11 | pacasmayo
# Processing Record 52 of Set 11 | cannonvale
# Processing Record 53 of Set 11 | cannonvale
# Processing Record 54 of Set 11 | sprockhovel
# Processing Record 55 of Set 11 | sprockhovel
# Processing Record 56 of Set 11 | ypsonas
# Processing Record 57 of Set 11 | ypsonas
# Processing Record 58 of Set 11 | nezhinka
# Processing Record 59 of Set 11 | nezhinka
# Processing Record 60 of Set 11 | charters towers
# Processing Record 61 of Set 11 | charters towers
# Processing Record 62 of Set 11 | baikonur
# Processing Record 63 of Set 11 | baikonur
# Processing Record 64 of Set 11 | inari
# Processing Record 65 of Set 11 | inari
# Processing Record 66 of Set 11 | nyagan
# Processing Record 67 of Set 11 | nyagan
# Processing Record 68 of Set 11 | awjilah
# Processing Record 69 of Set 11 | awjilah
# Processing Record 70 of Set 11 | tapolca
# Processing Record 71 of Set 11 | tapolca
# Processing Record 72 of Set 11 | muynoq
# Processing Record 73 of Set 11 | muynoq
# Processing Record 74 of Set 11 | barra do bugres
# Processing Record 75 of Set 11 | barra do bugres
# Processing Record 76 of Set 11 | hoemul-li
# Processing Record 77 of Set 11 | hoemul-li
# Processing Record 78 of Set 11 | warwick
# Processing Record 79 of Set 11 | warwick
# Processing Record 80 of Set 11 | malvan
# Processing Record 81 of Set 11 | malvan
# Processing Record 82 of Set 11 | namtsy
# Processing Record 83 of Set 11 | namtsy
# Processing Record 84 of Set 11 | nenagh
# Processing Record 85 of Set 11 | nenagh
# Processing Record 86 of Set 11 | takestan
# Processing Record 87 of Set 11 | takestan
# Processing Record 88 of Set 11 | ndjole
# Processing Record 89 of Set 11 | ndjole
# Processing Record 90 of Set 11 | presidencia de la plaza
# Processing Record 91 of Set 11 | presidencia de la plaza
# Processing Record 92 of Set 11 | tanumah
# Processing Record 93 of Set 11 | tanumah
# Processing Record 94 of Set 11 | kargasok
# Processing Record 95 of Set 11 | kargasok
# Processing Record 96 of Set 11 | haapavesi
# Processing Record 97 of Set 11 | haapavesi
# Processing Record 98 of Set 11 | cedeira
# Processing Record 99 of Set 11 | cedeira
# Processing Record 0 of Set 12 | itoman
# Processing Record 1 of Set 12 | itoman
# Processing Record 2 of Set 12 | belmonte
# Processing Record 3 of Set 12 | belmonte
# Processing Record 4 of Set 12 | muang phonsavan
# Processing Record 5 of Set 12 | muang phonsavan
# Processing Record 6 of Set 12 | sungai penuh
# Processing Record 7 of Set 12 | sungai penuh
# Processing Record 8 of Set 12 | diebougou
# Processing Record 9 of Set 12 | diebougou
# Processing Record 10 of Set 12 | northam
# Processing Record 11 of Set 12 | northam
# Processing Record 12 of Set 12 | campanario
# Processing Record 13 of Set 12 | campanario
# Processing Record 14 of Set 12 | ialibu
# Processing Record 15 of Set 12 | ialibu
# Processing Record 16 of Set 12 | robore
# Processing Record 17 of Set 12 | robore
# Processing Record 18 of Set 12 | pangkalanbuun
# Processing Record 19 of Set 12 | pangkalanbuun
# Processing Record 20 of Set 12 | chilca
# Processing Record 21 of Set 12 | chilca
# Processing Record 22 of Set 12 | vilyuchinsk
# Processing Record 23 of Set 12 | vilyuchinsk
# Processing Record 24 of Set 12 | vung tau
# Processing Record 25 of Set 12 | vung tau
# Processing Record 26 of Set 12 | halapitan
# Processing Record 27 of Set 12 | halapitan
# Processing Record 28 of Set 12 | kisangani
# Processing Record 29 of Set 12 | kisangani
# Processing Record 30 of Set 12 | iwaki
# Processing Record 31 of Set 12 | iwaki
# Processing Record 32 of Set 12 | tutong
# Processing Record 33 of Set 12 | tutong
# Processing Record 34 of Set 12 | zhengzhou
# Processing Record 35 of Set 12 | zhengzhou
# Processing Record 36 of Set 12 | bryne
# Processing Record 37 of Set 12 | bryne
# Processing Record 38 of Set 12 | clarkston heights-vineland
# Processing Record 39 of Set 12 | clarkston heights-vineland
# Processing Record 40 of Set 12 | port hedland
# Processing Record 41 of Set 12 | port hedland
# Processing Record 42 of Set 12 | huarmey
# Processing Record 43 of Set 12 | huarmey
# Processing Record 44 of Set 12 | barra de santo antonio
# Processing Record 45 of Set 12 | barra de santo antonio
# Processing Record 46 of Set 12 | puerto rico
# Processing Record 47 of Set 12 | puerto rico
# Processing Record 48 of Set 12 | dul'durga
# Processing Record 49 of Set 12 | dul'durga
# Processing Record 50 of Set 12 | betio village
# Processing Record 51 of Set 12 | betio village
# Processing Record 52 of Set 12 | el porvenir
# Processing Record 53 of Set 12 | el porvenir
# Processing Record 54 of Set 12 | ouadda
# Processing Record 55 of Set 12 | ouadda
# Processing Record 56 of Set 12 | porto novo
# Processing Record 57 of Set 12 | porto novo
# Processing Record 58 of Set 12 | rongelap
# Processing Record 59 of Set 12 | rongelap
# Processing Record 60 of Set 12 | rolla
# Processing Record 61 of Set 12 | rolla
# Processing Record 62 of Set 12 | namibe
# Processing Record 63 of Set 12 | namibe
# Processing Record 64 of Set 12 | toga village
# Processing Record 65 of Set 12 | toga village
# Processing Record 66 of Set 12 | lai
# Processing Record 67 of Set 12 | lai
# Processing Record 68 of Set 12 | ouellah
# Processing Record 69 of Set 12 | ouellah
# Processing Record 70 of Set 12 | machina
# Processing Record 71 of Set 12 | machina
# Processing Record 72 of Set 12 | zeya
# Processing Record 73 of Set 12 | zeya
# Processing Record 74 of Set 12 | tindouf
# Processing Record 75 of Set 12 | tindouf
# Processing Record 76 of Set 12 | palu
# Processing Record 77 of Set 12 | palu
# Processing Record 78 of Set 12 | al kharijah
# Processing Record 79 of Set 12 | al kharijah
# Processing Record 80 of Set 12 | rock springs
# Processing Record 81 of Set 12 | rock springs
# Processing Record 82 of Set 12 | summerside
# Processing Record 83 of Set 12 | summerside
# Processing Record 84 of Set 12 | kearney
# Processing Record 85 of Set 12 | kearney
# Processing Record 86 of Set 12 | nova vicosa
# Processing Record 87 of Set 12 | nova vicosa
# Processing Record 88 of Set 12 | rio san juan
# Processing Record 89 of Set 12 | rio san juan
# Processing Record 90 of Set 12 | troitsko-pechorsk
# Processing Record 91 of Set 12 | troitsko-pechorsk
# Processing Record 92 of Set 12 | bartica
# Processing Record 93 of Set 12 | bartica
# Processing Record 94 of Set 12 | santa cruz
# Processing Record 95 of Set 12 | santa cruz
# Processing Record 96 of Set 12 | moyale
# Processing Record 97 of Set 12 | moyale
# Processing Record 98 of Set 12 | santiago de cao
# Processing Record 99 of Set 12 | santiago de cao
# Processing Record 0 of Set 13 | kalmunai
# Processing Record 1 of Set 13 | kalmunai
# Processing Record 2 of Set 13 | whakatane
# Processing Record 3 of Set 13 | whakatane
