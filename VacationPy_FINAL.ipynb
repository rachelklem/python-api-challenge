# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
new_city_data_df = pd.read_csv("python-api-challenge/output_data/cities.csv", index_col="City_ID")

# Display sample data
new_city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           waitangi -43.9535 -176.5597     11.01        94
# 1        edinburgh of the seven seas -37.0676  -12.3116     14.52        75
# 2                          grytviken -54.2811  -36.5092      1.95        90
# 3                  port-aux-francais -49.3500   70.2167      4.70        65
# 4                           zaozersk  69.4005   32.4476     -4.30        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                18        0.89      NZ  1714326510
# 1                20       14.00      SH  1714326510
# 2                33        3.92      GS  1714326510
# 3                48       10.87      TF  1714326510
# 4                34        2.45      RU  1714326510

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = new_city_data_df.hvplot.points(
    "Lng",
    "Lat",
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.5,
    color = "City")

# Display the map
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
vacation_df = new_city_data_df.loc[(new_city_data_df['Max Temp'] <= 24) 
                                & (new_city_data_df['Max Temp'] > 15) 
                                & (new_city_data_df['Humidity'] <= 60) 
                                & (new_city_data_df['Wind Speed'] < 10)
                                & (new_city_data_df['Cloudiness'] <= 60)]

# Drop any rows with null values
vacation_df.dropna()

# Display sample data
vacation_df
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 35              rio grande -32.0350  -52.0986     20.06        53           0
# 46          ribeira grande  38.5167  -28.7000     18.22        59          20
# 57               zhanaozen  43.3000   52.8000     21.03        14           2
# 62             krasnyy yar  46.5331   48.3456     15.96        35          27
# 64                   dumas  35.8656 -101.9732     19.23        41           0
# 75           mar del plata -38.0023  -57.5575     19.41        35           0
# 87               berrechid  33.2655   -7.5875     16.90        55          40
# 89                luderitz -26.6481   15.1594     20.92        48           3
# 92           puerto madryn -42.7692  -65.0385     18.17        27           0
# 94                   crane  31.3974 -102.3501     23.15        20           0
# 107                  gazli  40.1333   63.4500     16.21        16           0
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = vacation_df.copy()
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# City_ID
# 35              rio grande      BR -32.0350  -52.0986        53
# 46          ribeira grande      PT  38.5167  -28.7000        59
# 57               zhanaozen      KZ  43.3000   52.8000        14
# 62             krasnyy yar      RU  46.5331   48.3456        35
# 64                   dumas      US  35.8656 -101.9732        41
# 75           mar del plata      AR -38.0023  -57.5575        35
# 87               berrechid      MA  33.2655   -7.5875        55
# 89                luderitz     NaN -26.6481   15.1594        48
# 92           puerto madryn      AR -42.7692  -65.0385        27
# 94                   crane      US  31.3974 -102.3501        20
# 107                  gazli      UZ  40.1333   63.4500        16
# 113               subotica      RS  46.1000   19.6667        59
# 114                  kaoma      ZM -14.7833   24.8000        48
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accommodation.hotel"
limit = 1
params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key    
}
    
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, 'Lat']
    longitude = hotel_df.loc[index, 'Lng']

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params['filters'] = f"circle:{longitude},{latitude},{radius}"
    params['bias'] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary   
    name_address = requests.get(base_url, params=params, verify=False)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# ribeira grande - nearest hotel: Hospedaria JSF
# zhanaozen - nearest hotel: No hotel found
# krasnyy yar - nearest hotel: Веранда
# dumas - nearest hotel: Red Roof Inn
# mar del plata - nearest hotel: Gran hotel Mónaco
# berrechid - nearest hotel: ONOMO
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# puerto madryn - nearest hotel: Hotel Gran Palace
# crane - nearest hotel: Mainstay Suites
# gazli - nearest hotel: Bukhara Desert Oasis & Spa
# subotica - nearest hotel: Хотел Патрија
# kaoma - nearest hotel: Pumulo Pardway Lodge
# praia da vitoria - nearest hotel: Salles
# caconda - nearest hotel: Hotel Ganda
# westport - nearest hotel: Norwalk Inn and Conference Center
# camargo - nearest hotel: Hotel Santa Fe
# geraldton - nearest hotel: Ocean Centre Hotel
# sabzevar - nearest hotel: مامورسرا مخابرات سبزوار
# ridgecrest - nearest hotel: Best Western China Lake Inn
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    tiles = "CartoLight",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color = "City",
    hover_cols = 'all',
    use_index = False,
    scale = 1.5,
    legend = 'right'
)

# Display the map
hotel_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
